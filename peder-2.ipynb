# %%
#!pip install openpyxl

# %%
import seaborn as sns
from statistics import *
from statistics import stdev
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import openpyxl

# %%
'''file = r'../input/public/Public_transportation_infrastructure.xlsx'
xl = pd.ExcelFile(file)
print(xl.sheet_names)
df1 = xl.parse('Sheet6')'''
# Out:
# "file = r'../input/public/Public_transportation_infrastructure.xlsx'\nxl = pd.ExcelFile(file)\nprint(xl.sheet_names)\ndf1 = xl.parse('Sheet6')"

# %%
'''file = r'../input/bysykk/Bysykkeloversikt_2019.xlsx'
xl = pd.ExcelFile(file)
print(xl.sheet_names)
df1 = xl.parse('Analyse')'''
# Out:
# "file = r'../input/bysykk/Bysykkeloversikt_2019.xlsx'\nxl = pd.ExcelFile(file)\nprint(xl.sheet_names)\ndf1 = xl.parse('Analyse')"

# %%
'''df1 = xl.parse('juli_2019')
df1'''
# Out:
# "df1 = xl.parse('juli_2019')\ndf1"

# %%
'''
file = r'../input/public/Public_transportation_infrastructure.xlsx'
xl2 = pd.ExcelFile(file)
print(xl2.sheet_names)
#df1 = xl.parse('Analyse')
df10 = pd.read_excel(xl2, 'Sheet6')
df10.to_pickle('Sheet6.pkl')
'''
# Out:
# "\nfile = r'../input/public/Public_transportation_infrastructure.xlsx'\nxl2 = pd.ExcelFile(file)\nprint(xl2.sheet_names)\n#df1 = xl.parse('Analyse')\ndf10 = pd.read_excel(xl2, 'Sheet6')\ndf10.to_pickle('Sheet6.pkl')\n"

# %%
#['Analyse', 'april_2019', 'mai_2019', 'juni_2019', 'juli_2019', 'august_2019', 'september_2019', 'oktober_2019']

# %%
'''df1 = pd.read_excel(xl, 'Analyse')
df1.to_pickle('Analyse.pkl')

df2 = pd.read_excel(xl, 'april_2019')
df2.to_pickle('april_2019.pkl')

df3 = pd.read_excel(xl, 'mai_2019')
df3.to_pickle('mai_2019.pkl')

df4 = pd.read_excel(xl, 'juni_2019')
df4.to_pickle('juni_2019.pkl')

df5 = pd.read_excel(xl, 'juli_2019')
df5.to_pickle('juli_2019.pkl')

df6 = pd.read_excel(xl, 'august_2019')
df6.to_pickle('august_2019.pkl')

df7 = pd.read_excel(xl, 'september_2019')
df7.to_pickle('september_2019.pkl')

df8 = pd.read_excel(xl, 'oktober_2019')
df8.to_pickle('oktober_2019.pkl')
'''
# Out:
# "df1 = pd.read_excel(xl, 'Analyse')\ndf1.to_pickle('Analyse.pkl')\n\ndf2 = pd.read_excel(xl, 'april_2019')\ndf2.to_pickle('april_2019.pkl')\n\ndf3 = pd.read_excel(xl, 'mai_2019')\ndf3.to_pickle('mai_2019.pkl')\n\ndf4 = pd.read_excel(xl, 'juni_2019')\ndf4.to_pickle('juni_2019.pkl')\n\ndf5 = pd.read_excel(xl, 'juli_2019')\ndf5.to_pickle('juli_2019.pkl')\n\ndf6 = pd.read_excel(xl, 'august_2019')\ndf6.to_pickle('august_2019.pkl')\n\ndf7 = pd.read_excel(xl, 'september_2019')\ndf7.to_pickle('september_2019.pkl')\n\ndf8 = pd.read_excel(xl, 'oktober_2019')\ndf8.to_pickle('oktober_2019.pkl')\n"

# %%
df1 = pd.read_pickle(r'../input/dataset-pkl/Analyse.pkl')
df3 = pd.read_pickle(r'../input/dataset-pkl/april_2019.pkl')
df4 = pd.read_pickle(r'../input/dataset-pkl/mai_2019.pkl')
df5 = pd.read_pickle(r'../input/dataset-pkl/juni_2019.pkl')
df6 = pd.read_pickle(r'../input/dataset-pkl/juli_2019.pkl')
df7 = pd.read_pickle(r'../input/dataset-pkl/august_2019.pkl')
df8 = pd.read_pickle(r'../input/dataset-pkl/september_2019.pkl')
df9 = pd.read_pickle(r'../input/dataset-pkl/oktober_2019.pkl')
df10 = pd.read_pickle(r'../input/sheet6/Sheet6.pkl')

# %%
df1=df1.dropna(axis=1,how='all')
df1
# Out:
#     2019-04-01 00:00:00          Unnamed: 1 2019-05-01 00:00:00  \
# 0          Radetiketter  Antall av ended_at        Radetiketter
# 1        7 Juni Plassen                1293      7 Juni Plassen
# 2             Adamstuen                 567           Adamstuen
# 3                   AHO                1799                 AHO
# 4             Akersgata                2418           Akersgata
# ..                  ...                 ...                 ...
# 249                 NaN                 NaN                 NaN
# 250                 NaN                 NaN                 NaN
# 251                 NaN                 NaN                 NaN
# 252                 NaN                 NaN                 NaN
# 253                 NaN                 NaN                 NaN
#
#              Unnamed: 4 2019-06-01 00:00:00          Unnamed: 7  \
# 0    Antall av ended_at        Radetiketter  Antall av ended_at
# 1                  1879      7 Juni Plassen                1943
# 2                   904           Adamstuen                 825
# 3                  2331                 AHO                2244
# 4                  3116           Akersgata                3021
# ..                  ...                 ...                 ...
# 249                 NaN                 NaN                 NaN
# 250                 NaN                 NaN                 NaN
# 251                 NaN                 NaN                 NaN
# 252                 NaN                 NaN                 NaN
# 253                 NaN                 NaN                 NaN
#
#     2019-07-01 00:00:00         Unnamed: 10        2019-08-01 00:00:00  \
# 0          Radetiketter  Antall av ended_at               Radetiketter
# 1        7 Juni Plassen                1565             7 Juni Plassen
# 2             Adamstuen                 671                  Adamstuen
# 3                   AHO                1865                        AHO
# 4             Akersgata                2617                  Akersgata
# ..                  ...                 ...                        ...
# 249          Økernveien                 302                     Vulkan
# 250            Totalsum              310955                  Vålerenga
# 251                 NaN                 NaN  Vår Frelsers gravlund sør
# 252                 NaN                 NaN                 Økernveien
# 253                 NaN                 NaN                   Totalsum
#
#             Unnamed: 13 2019-09-01 00:00:00         Unnamed: 16  \
# 0    Antall av ended_at        Radetiketter  Antall av ended_at
# 1                  2622      7 Juni Plassen                2546
# 2                   899           Adamstuen                 745
# 3                  2691                 AHO                2362
# 4                  3464           Akersgata                2747
# ..                  ...                 ...                 ...
# 249                2709            Totalsum              292586
# 250                1087                 NaN                 NaN
# 251                3375                 NaN                 NaN
# 252                 527                 NaN                 NaN
# 253              389270                 NaN                 NaN
#
#     2019-10-01 00:00:00         Unnamed: 19
# 0          Radetiketter  Antall av ended_at
# 1        7 Juni Plassen                1718
# 2             Adamstuen                 473
# 3                   AHO                1662
# 4             Akersgata                2056
# ..                  ...                 ...
# 249          Økernveien                 185
# 250            Totalsum              193868
# 251                 NaN                 NaN
# 252                 NaN                 NaN
# 253                 NaN                 NaN
#
# [254 rows x 14 columns]

# %%
for col in df1.columns:
    print(col)
# Out:
# 2019-04-01 00:00:00
# Unnamed: 1
# 2019-05-01 00:00:00
# Unnamed: 4
# 2019-06-01 00:00:00
# Unnamed: 7
# 2019-07-01 00:00:00
# Unnamed: 10
# 2019-08-01 00:00:00
# Unnamed: 13
# 2019-09-01 00:00:00
# Unnamed: 16
# 2019-10-01 00:00:00
# Unnamed: 19

# %%
df1=df1.rename(columns={'Unnamed: 1':'c_april'})
df1=df1.rename(columns={'Unnamed: 4':'c_may'})
df1=df1.rename(columns={'Unnamed: 7':'c_jun'})
df1=df1.rename(columns={'Unnamed: 10':'c_july'})
df1=df1.rename(columns={'Unnamed: 13':'c_aug'})
df1=df1.rename(columns={'Unnamed: 16':'c_sep'})
df1=df1.rename(columns={'Unnamed: 19':'c_oct'})

df1
# Out:
#     2019-04-01 00:00:00             c_april 2019-05-01 00:00:00  \
# 0          Radetiketter  Antall av ended_at        Radetiketter
# 1        7 Juni Plassen                1293      7 Juni Plassen
# 2             Adamstuen                 567           Adamstuen
# 3                   AHO                1799                 AHO
# 4             Akersgata                2418           Akersgata
# ..                  ...                 ...                 ...
# 249                 NaN                 NaN                 NaN
# 250                 NaN                 NaN                 NaN
# 251                 NaN                 NaN                 NaN
# 252                 NaN                 NaN                 NaN
# 253                 NaN                 NaN                 NaN
#
#                   c_may 2019-06-01 00:00:00               c_jun  \
# 0    Antall av ended_at        Radetiketter  Antall av ended_at
# 1                  1879      7 Juni Plassen                1943
# 2                   904           Adamstuen                 825
# 3                  2331                 AHO                2244
# 4                  3116           Akersgata                3021
# ..                  ...                 ...                 ...
# 249                 NaN                 NaN                 NaN
# 250                 NaN                 NaN                 NaN
# 251                 NaN                 NaN                 NaN
# 252                 NaN                 NaN                 NaN
# 253                 NaN                 NaN                 NaN
#
#     2019-07-01 00:00:00              c_july        2019-08-01 00:00:00  \
# 0          Radetiketter  Antall av ended_at               Radetiketter
# 1        7 Juni Plassen                1565             7 Juni Plassen
# 2             Adamstuen                 671                  Adamstuen
# 3                   AHO                1865                        AHO
# 4             Akersgata                2617                  Akersgata
# ..                  ...                 ...                        ...
# 249          Økernveien                 302                     Vulkan
# 250            Totalsum              310955                  Vålerenga
# 251                 NaN                 NaN  Vår Frelsers gravlund sør
# 252                 NaN                 NaN                 Økernveien
# 253                 NaN                 NaN                   Totalsum
#
#                   c_aug 2019-09-01 00:00:00               c_sep  \
# 0    Antall av ended_at        Radetiketter  Antall av ended_at
# 1                  2622      7 Juni Plassen                2546
# 2                   899           Adamstuen                 745
# 3                  2691                 AHO                2362
# 4                  3464           Akersgata                2747
# ..                  ...                 ...                 ...
# 249                2709            Totalsum              292586
# 250                1087                 NaN                 NaN
# 251                3375                 NaN                 NaN
# 252                 527                 NaN                 NaN
# 253              389270                 NaN                 NaN
#
#     2019-10-01 00:00:00               c_oct
# 0          Radetiketter  Antall av ended_at
# 1        7 Juni Plassen                1718
# 2             Adamstuen                 473
# 3                   AHO                1662
# 4             Akersgata                2056
# ..                  ...                 ...
# 249          Økernveien                 185
# 250            Totalsum              193868
# 251                 NaN                 NaN
# 252                 NaN                 NaN
# 253                 NaN                 NaN
#
# [254 rows x 14 columns]

# %%
df1.columns.tolist()
# Out:
# [datetime.datetime(2019, 4, 1, 0, 0),
#  'c_april',
#  datetime.datetime(2019, 5, 1, 0, 0),
#  'c_may',
#  datetime.datetime(2019, 6, 1, 0, 0),
#  'c_jun',
#  datetime.datetime(2019, 7, 1, 0, 0),
#  'c_july',
#  datetime.datetime(2019, 8, 1, 0, 0),
#  'c_aug',
#  datetime.datetime(2019, 9, 1, 0, 0),
#  'c_sep',
#  datetime.datetime(2019, 10, 1, 0, 0),
#  'c_oct']

# %%
import datetime
import os
import csv
from datetime import datetime
df1 = df1.rename(columns={datetime.strptime('2019-04-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '04'})
df1 = df1.rename(columns={datetime.strptime('2019-05-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '05'})
df1 = df1.rename(columns={datetime.strptime('2019-06-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '06'})
df1 = df1.rename(columns={datetime.strptime('2019-07-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '07'})
df1 = df1.rename(columns={datetime.strptime('2019-08-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '08'})
df1 = df1.rename(columns={datetime.strptime('2019-09-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '09'})
df1 = df1.rename(columns={datetime.strptime('2019-10-01 00:00:00', '%Y-%m-%d %H:%M:%S'): '10'})

# %%
df1
# Out:
#                  04             c_april              05               c_may  \
# 0      Radetiketter  Antall av ended_at    Radetiketter  Antall av ended_at
# 1    7 Juni Plassen                1293  7 Juni Plassen                1879
# 2         Adamstuen                 567       Adamstuen                 904
# 3               AHO                1799             AHO                2331
# 4         Akersgata                2418       Akersgata                3116
# ..              ...                 ...             ...                 ...
# 249             NaN                 NaN             NaN                 NaN
# 250             NaN                 NaN             NaN                 NaN
# 251             NaN                 NaN             NaN                 NaN
# 252             NaN                 NaN             NaN                 NaN
# 253             NaN                 NaN             NaN                 NaN
#
#                  06               c_jun              07              c_july  \
# 0      Radetiketter  Antall av ended_at    Radetiketter  Antall av ended_at
# 1    7 Juni Plassen                1943  7 Juni Plassen                1565
# 2         Adamstuen                 825       Adamstuen                 671
# 3               AHO                2244             AHO                1865
# 4         Akersgata                3021       Akersgata                2617
# ..              ...                 ...             ...                 ...
# 249             NaN                 NaN      Økernveien                 302
# 250             NaN                 NaN        Totalsum              310955
# 251             NaN                 NaN             NaN                 NaN
# 252             NaN                 NaN             NaN                 NaN
# 253             NaN                 NaN             NaN                 NaN
#
#                             08               c_aug              09  \
# 0                 Radetiketter  Antall av ended_at    Radetiketter
# 1               7 Juni Plassen                2622  7 Juni Plassen
# 2                    Adamstuen                 899       Adamstuen
# 3                          AHO                2691             AHO
# 4                    Akersgata                3464       Akersgata
# ..                         ...                 ...             ...
# 249                     Vulkan                2709        Totalsum
# 250                  Vålerenga                1087             NaN
# 251  Vår Frelsers gravlund sør                3375             NaN
# 252                 Økernveien                 527             NaN
# 253                   Totalsum              389270             NaN
#
#                   c_sep              10               c_oct
# 0    Antall av ended_at    Radetiketter  Antall av ended_at
# 1                  2546  7 Juni Plassen                1718
# 2                   745       Adamstuen                 473
# 3                  2362             AHO                1662
# 4                  2747       Akersgata                2056
# ..                  ...             ...                 ...
# 249              292586      Økernveien                 185
# 250                 NaN        Totalsum              193868
# 251                 NaN             NaN                 NaN
# 252                 NaN             NaN                 NaN
# 253                 NaN             NaN                 NaN
#
# [254 rows x 14 columns]

# %%
df1.to_dict()
# Out:
# {'04': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Nord',
#   10: 'Arkaden Sør',
#   11: 'Arkitekt Rivertz Plass',
#   12: 'Badebakken',
#   13: 'Bak Niels Treschows hus nord',
#   14: 'Bak Niels Treschows hus sør',
#   15: 'Bankplassen',
#   16: 'Bentsebrugata',
#   17: 'Bernt Ankers gate',
#   18: 'BI Nydalen',
#   19: 'Birkelunden',
#   20: "Biskop Gunnerus' gate",
#   21: 'Bislett Stadion',
#   22: 'Bislettgata',
#   23: 'Bjerregaards gate',
#   24: 'Bjerregaardsgate Øst',
#   25: 'Bjølsen mølle',
#   26: 'Bjølsen Studentby',
#   27: 'Bjølsendumpa',
#   28: 'Bjørvika',
#   29: 'Blindern studentparkering',
#   30: 'Bogstadveien',
#   31: 'Botanisk Hage sør',
#   32: 'Botanisk hage sør-vest',
#   33: 'Botanisk Hage vest',
#   34: 'Briskeby',
#   35: 'Bryn T-Bane',
#   36: 'Bygdøy allé',
#   37: 'Bøkkerveien',
#   38: 'Carl Berners plass sør',
#   39: 'Chr. Michelsens Gate',
#   40: 'Colbjørnsens gate',
#   41: 'Colletts gate',
#   42: 'Colosseum Kino',
#   43: 'Det Teologiske fakultet',
#   44: 'Diakonhjemmet',
#   45: 'Dokkveien',
#   46: 'Drammensveien',
#   47: 'Dyvekes bru',
#   48: 'Dælenenggata',
#   49: 'Edvard Storms gate',
#   50: 'Ensjø T-Bane',
#   51: 'Ensjøveien',
#   52: 'Fagerheimgata',
#   53: 'Filipstadveien',
#   54: 'Finnmarksgata',
#   55: 'Forskningsveien',
#   56: 'Fram-gården',
#   57: 'Fred Olsens gate',
#   58: 'Fredensborg',
#   59: 'Friggfeltet',
#   60: 'Frogner plass',
#   61: 'Frogner Stadion',
#   62: 'Frogner Tennisklubb',
#   63: 'Frognerbadet',
#   64: 'Frognerstranda',
#   65: 'Frognerveien',
#   66: 'Frøen T-bane',
#   67: 'Furulund',
#   68: 'Fyrstikktorget',
#   69: 'Fysikkbygningen',
#   70: 'Galgeberg',
#   71: 'Gaustad T-bane',
#   72: 'Georg Morgenstiernes hus',
#   73: 'Gimle Kino',
#   74: 'Goethe Institut',
#   75: 'Grenseveien',
#   76: 'Griffenfeldts gate',
#   77: 'Grünerhagen Nord',
#   78: 'Grønlands torg',
#   79: 'Hallénparken',
#   80: 'Hallings gate',
#   81: 'Hammersborg Torg',
#   82: 'Hans Nielsen Hauges plass',
#   83: 'Hasle',
#   84: 'Hasle Torg',
#   85: 'HasleLinje',
#   86: 'Hausmanns bru',
#   87: 'Hausmanns gate',
#   88: 'Helga Helgesens plass',
#   89: 'Henrik Ibsens gate',
#   90: 'HiOA',
#   91: 'Hoff terrasse holdeplass',
#   92: 'Hoffsveien',
#   93: 'Holbergs Plass',
#   94: 'Huitfeldts gate',
#   95: 'Huk',
#   96: 'Hydroparken',
#   97: 'Idioten',
#   98: 'Ila',
#   99: 'Jakob kirke',
#   100: 'Jarlsborgveien',
#   101: 'Jenny Braatens Plass',
#   102: 'Jens Bjelkes gate',
#   103: 'Jernbanetorget',
#   104: 'Jess Carlsens gate',
#   105: 'John Colletts plass',
#   106: 'Jordalgata',
#   107: 'Kampen park Øst',
#   108: 'Karenlyst allé',
#   109: 'Kirkegata 15',
#   110: 'Kirkeristen',
#   111: 'Kirkeveien',
#   112: 'Kjeld Stubs gate',
#   113: 'Kontraskjæret',
#   114: "Krebs' gate",
#   115: 'Kværnerbyen',
#   116: 'Københavngata busstopp',
#   117: 'Lakkegata',
#   118: 'Landstads gate',
#   119: 'Langkaia',
#   120: 'Lille Grensen',
#   121: 'Lilleborgbanen',
#   122: 'Linaaes gate',
#   123: 'Lindern',
#   124: 'Lodalen busstopp',
#   125: 'Lørenveien',
#   126: 'Mailundveien',
#   127: 'Majorstua skole',
#   128: 'Majorstuen',
#   129: 'Majorstuen t-bane',
#   130: 'Majorstuveien',
#   131: 'Mandalls gate',
#   132: 'Marienlyst',
#   133: 'Marienlystparken',
#   134: 'Meltzers gate',
#   135: 'Monolittveien',
#   136: 'Munkedamsveien',
#   137: 'Munkegata trikkestopp',
#   138: 'Myraløkka Øst',
#   139: 'Mølleparken',
#   140: 'Møllergata',
#   141: 'Nedre Slottsgate',
#   142: 'Nordre gate',
#   143: 'Norsk Folkemuseum',
#   144: 'Nydalen',
#   145: 'Nylandsveien',
#   146: 'Olaf Ryes plass',
#   147: 'Olav Vs gate',
#   148: 'Oscars gate',
#   149: 'Oslo Handelsgymnasium',
#   150: 'Oslo Hospital',
#   151: 'Oslo Plaza',
#   152: 'Over Rådhusgata',
#   153: 'Paléhaven',
#   154: 'Parkveien',
#   155: 'Pilestredet',
#   156: 'Pilestredet 63',
#   157: 'Pilestredet Studenthus',
#   158: 'Riddervoldplass',
#   159: 'Ringnes Park',
#   160: 'Rolf Wickstrøms vei',
#   161: 'Ruseløkkgården',
#   162: 'Rådhusbrygge 4',
#   163: 'Rådhusgata',
#   164: 'Saga Kino',
#   165: 'Sagene bussholdeplass',
#   166: 'Salt',
#   167: 'Schives gate',
#   168: 'Schous plass',
#   169: 'Schous plass trikkestopp',
#   170: 'Sentrum Scene',
#   171: 'Sinsen T-bane',
#   172: 'Sinsenveien',
#   173: 'Sirkustomta',
#   174: 'Sjølyst',
#   175: 'Sjøsiden vest',
#   176: 'Sjøsiden øst',
#   177: 'Skarpsnoparken',
#   178: 'Skillebekk',
#   179: 'Skippergata',
#   180: 'Skovveien',
#   181: 'Skråninga',
#   182: 'Skøyen',
#   183: 'Skøyen Stasjon',
#   184: 'Slemdalsveien',
#   185: 'Slottsparken Øst',
#   186: 'Sofienberggata',
#   187: 'Sofienbergparken nord',
#   188: 'Sofienbergparken nordvest',
#   189: 'Sofienbergparken sør',
#   190: 'Sognsveien',
#   191: 'Sommerfrydhagen',
#   192: 'Sotahjørnet',
#   193: 'Spikersuppa Vest',
#   194: 'Spikersuppa Øst',
#   195: 'St. Hanshaugen',
#   196: 'St. Hanshaugen park nord',
#   197: 'St. Hanshaugen park sør',
#   198: 'St. Hanshaugen park vest',
#   199: 'St. Olavs gate',
#   200: 'Stavangergata',
#   201: 'Stensgata',
#   202: 'Stensparken',
#   203: 'Stockfleths gate',
#   204: 'Storgata',
#   205: 'Storo Storsenter',
#   206: 'Studenterlunden',
#   207: 'Studentparlamentet',
#   208: 'Suhms gate',
#   209: 'Sukkerbiten',
#   210: 'Søndre gate',
#   211: 'Sørvest for Slottsparken',
#   212: 'Tannlegehøyskolen',
#   213: 'Thereses gate',
#   214: 'Thomas Heftyes plass',
#   215: 'Thune',
#   216: 'Tjuvholmen',
#   217: 'Tordenskiolds gate',
#   218: 'Torggata',
#   219: 'Torshovdalen øst',
#   220: 'Torshovparken vest',
#   221: 'Trelastgata',
#   222: 'Trondheimsveien',
#   223: 'Tøyen skole',
#   224: 'Tøyenbekken',
#   225: 'Tøyenparken',
#   226: 'Tåsen Senter',
#   227: 'Tåsenløkka',
#   228: 'Uelands gate',
#   229: 'Ullevål sykehus',
#   230: 'Ullevålsalléen',
#   231: 'Ullevålsveien',
#   232: 'Uranienborgparken',
#   233: 'Uranienborgveien',
#   234: 'Valkyrieplassen',
#   235: 'Vaterlandsparken',
#   236: 'Vaterlandsparken II',
#   237: 'Vestkanttorvet',
#   238: 'Vippetangen vest',
#   239: 'Vippetangen øst',
#   240: 'Volvat',
#   241: 'Vulkan',
#   242: 'Vålerenga',
#   243: 'Vår Frelsers gravlund sør',
#   244: 'Økernveien',
#   245: 'Totalsum',
#   246: nan,
#   247: nan,
#   248: nan,
#   249: nan,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  'c_april': {0: 'Antall av ended_at',
#   1: 1293,
#   2: 567,
#   3: 1799,
#   4: 2418,
#   5: 3238,
#   6: 1395,
#   7: 998,
#   8: 543,
#   9: 1315,
#   10: 1103,
#   11: 352,
#   12: 226,
#   13: 318,
#   14: 175,
#   15: 1846,
#   16: 606,
#   17: 1511,
#   18: 524,
#   19: 2258,
#   20: 1097,
#   21: 2299,
#   22: 696,
#   23: 1545,
#   24: 621,
#   25: 186,
#   26: 565,
#   27: 275,
#   28: 2058,
#   29: 144,
#   30: 1619,
#   31: 1968,
#   32: 739,
#   33: 925,
#   34: 545,
#   35: 137,
#   36: 516,
#   37: 93,
#   38: 1162,
#   39: 845,
#   40: 455,
#   41: 189,
#   42: 622,
#   43: 281,
#   44: 214,
#   45: 1455,
#   46: 426,
#   47: 809,
#   48: 612,
#   49: 1136,
#   50: 168,
#   51: 226,
#   52: 1262,
#   53: 2083,
#   54: 501,
#   55: 161,
#   56: 1031,
#   57: 1732,
#   58: 1569,
#   59: 264,
#   60: 1376,
#   61: 691,
#   62: 238,
#   63: 454,
#   64: 1398,
#   65: 585,
#   66: 111,
#   67: 113,
#   68: 186,
#   69: 336,
#   70: 615,
#   71: 70,
#   72: 297,
#   73: 999,
#   74: 129,
#   75: 106,
#   76: 570,
#   77: 1065,
#   78: 1857,
#   79: 1092,
#   80: 770,
#   81: 1377,
#   82: 460,
#   83: 73,
#   84: 309,
#   85: 67,
#   86: 752,
#   87: 886,
#   88: 2960,
#   89: 900,
#   90: 1151,
#   91: 470,
#   92: 351,
#   93: 1202,
#   94: 1265,
#   95: 1191,
#   96: 811,
#   97: 228,
#   98: 183,
#   99: 2292,
#   100: 91,
#   101: 593,
#   102: 1647,
#   103: 3045,
#   104: 1487,
#   105: 154,
#   106: 540,
#   107: 61,
#   108: 1473,
#   109: 666,
#   110: 1940,
#   111: 222,
#   112: 413,
#   113: 1107,
#   114: 455,
#   115: 1144,
#   116: 302,
#   117: 1403,
#   118: 508,
#   119: 597,
#   120: 1450,
#   121: 572,
#   122: 1173,
#   123: 159,
#   124: 272,
#   125: 328,
#   126: 126,
#   127: 519,
#   128: 1739,
#   129: 146,
#   130: 629,
#   131: 993,
#   132: 340,
#   133: 481,
#   134: 258,
#   135: 114,
#   136: 611,
#   137: 1601,
#   138: 687,
#   139: 835,
#   140: 1317,
#   141: 710,
#   142: 1462,
#   143: 909,
#   144: 115,
#   145: 1375,
#   146: 3333,
#   147: 1546,
#   148: 1149,
#   149: 1008,
#   150: 970,
#   151: 923,
#   152: 958,
#   153: 2690,
#   154: 1204,
#   155: 504,
#   156: 750,
#   157: 709,
#   158: 503,
#   159: 3039,
#   160: 25,
#   161: 925,
#   162: 6101,
#   163: 832,
#   164: 1926,
#   165: 631,
#   166: 871,
#   167: 492,
#   168: 2633,
#   169: 1576,
#   170: 2639,
#   171: 140,
#   172: 211,
#   173: 691,
#   174: 408,
#   175: 1902,
#   176: 3281,
#   177: 197,
#   178: 1197,
#   179: 884,
#   180: 780,
#   181: 1743,
#   182: 1019,
#   183: 387,
#   184: 704,
#   185: 754,
#   186: 951,
#   187: 1897,
#   188: 1578,
#   189: 995,
#   190: 311,
#   191: 1290,
#   192: 288,
#   193: 2413,
#   194: 1971,
#   195: 939,
#   196: 311,
#   197: 502,
#   198: 548,
#   199: 2079,
#   200: 408,
#   201: 669,
#   202: 799,
#   203: 168,
#   204: 1272,
#   205: 524,
#   206: 1764,
#   207: 767,
#   208: 522,
#   209: 3534,
#   210: 1937,
#   211: 324,
#   212: 350,
#   213: 330,
#   214: 1213,
#   215: 596,
#   216: 3301,
#   217: 599,
#   218: 4493,
#   219: 260,
#   220: 291,
#   221: 908,
#   222: 391,
#   223: 2197,
#   224: 1490,
#   225: 525,
#   226: 102,
#   227: 236,
#   228: 474,
#   229: 657,
#   230: 162,
#   231: 271,
#   232: 428,
#   233: 1131,
#   234: 946,
#   235: 2633,
#   236: 985,
#   237: 558,
#   238: 1555,
#   239: 734,
#   240: 186,
#   241: 1632,
#   242: 333,
#   243: 2067,
#   244: 212,
#   245: 235713,
#   246: nan,
#   247: nan,
#   248: nan,
#   249: nan,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  '05': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Nord',
#   10: 'Arkaden Sør',
#   11: 'Arkitekt Rivertz Plass',
#   12: 'Badebakken',
#   13: 'Bak Niels Treschows hus nord',
#   14: 'Bak Niels Treschows hus sør',
#   15: 'Bankplassen',
#   16: 'Bentsebrugata',
#   17: 'Bernt Ankers gate',
#   18: 'BI Nydalen',
#   19: 'Birkelunden',
#   20: "Biskop Gunnerus' gate",
#   21: 'Bislett Stadion',
#   22: 'Bislettgata',
#   23: 'Bjerregaards gate',
#   24: 'Bjerregaardsgate Øst',
#   25: 'Bjølsen mølle',
#   26: 'Bjølsen Studentby',
#   27: 'Bjølsendumpa',
#   28: 'Bjørvika',
#   29: 'Blindern studentparkering',
#   30: 'Bogstadveien',
#   31: 'Botanisk Hage sør',
#   32: 'Botanisk hage sør-vest',
#   33: 'Botanisk Hage vest',
#   34: 'Briskeby',
#   35: 'Bryn T-Bane',
#   36: 'Bygdøy allé',
#   37: 'Bøkkerveien',
#   38: 'Carl Berners plass sør',
#   39: 'Chr. Michelsens Gate',
#   40: 'Colbjørnsens gate',
#   41: 'Colosseum Kino',
#   42: 'Det Teologiske fakultet',
#   43: 'Diakonhjemmet',
#   44: 'Dokkveien',
#   45: 'Dyvekes bru',
#   46: 'Dælenenggata',
#   47: 'Edvard Storms gate',
#   48: 'Elisenberg',
#   49: 'Ensjø T-Bane',
#   50: 'Ensjøveien',
#   51: 'Fagerheimgata',
#   52: 'Filipstadveien',
#   53: 'Finnmarksgata',
#   54: 'Forskningsveien',
#   55: 'Fram-gården',
#   56: 'Fred Olsens gate',
#   57: 'Fredensborg',
#   58: 'Friggfeltet',
#   59: 'Frogner plass',
#   60: 'Frogner Stadion',
#   61: 'Frogner Tennisklubb',
#   62: 'Frognerbadet',
#   63: 'Frognerstranda',
#   64: 'Frognerveien',
#   65: 'Frøen T-bane',
#   66: 'Furulund',
#   67: 'Fyrstikktorget',
#   68: 'Fysikkbygningen',
#   69: 'Galgeberg',
#   70: 'Gaustad T-bane',
#   71: 'Georg Morgenstiernes hus',
#   72: 'Gimle Kino',
#   73: 'Grenseveien',
#   74: 'Griffenfeldts gate',
#   75: 'Grünerhagen Nord',
#   76: 'Grønlands torg',
#   77: 'Hallénparken',
#   78: 'Hallings gate',
#   79: 'Hammersborg Torg',
#   80: 'Hans Nielsen Hauges plass',
#   81: 'Hasle',
#   82: 'Hasle Torg',
#   83: 'HasleLinje',
#   84: 'Hausmanns bru',
#   85: 'Hausmanns gate',
#   86: 'Helga Helgesens plass',
#   87: 'Henrik Ibsens gate',
#   88: 'Henrik Wergelands allé',
#   89: 'HiOA',
#   90: 'Hoff terrasse holdeplass',
#   91: 'Hoffsveien',
#   92: 'Holbergs Plass',
#   93: 'Huitfeldts gate',
#   94: 'Huk',
#   95: 'Hydroparken',
#   96: 'Idioten',
#   97: 'Ila',
#   98: 'Jakob kirke',
#   99: 'Jarlsborgveien',
#   100: 'Jenny Braatens Plass',
#   101: 'Jens Bjelkes gate',
#   102: 'Jernbanetorget',
#   103: 'Jess Carlsens gate',
#   104: 'John Colletts plass',
#   105: 'Jordalgata',
#   106: 'Kampen park Øst',
#   107: 'Karenlyst allé',
#   108: 'Kirkegata 15',
#   109: 'Kirkeristen',
#   110: 'Kirkeveien',
#   111: 'Kjeld Stubs gate',
#   112: 'Kontraskjæret',
#   113: "Krebs' gate",
#   114: 'Kværnerbyen',
#   115: 'Københavngata busstopp',
#   116: 'Lakkegata',
#   117: 'Landstads gate',
#   118: 'Langkaia',
#   119: 'Lille Grensen',
#   120: 'Lilleborgbanen',
#   121: 'Linaaes gate',
#   122: 'Lindern',
#   123: 'Lodalen busstopp',
#   124: 'Lørenveien',
#   125: 'Mailundveien',
#   126: 'Majorstua skole',
#   127: 'Majorstuen',
#   128: 'Majorstuen t-bane',
#   129: 'Majorstuveien',
#   130: 'Mandalls gate',
#   131: 'Marienlyst',
#   132: 'Marienlystparken',
#   133: 'Meltzers gate',
#   134: 'Monolittveien',
#   135: 'Munkedamsveien',
#   136: 'Munkegata trikkestopp',
#   137: 'Myraløkka Øst',
#   138: 'Mølleparken',
#   139: 'Møllergata',
#   140: 'Nedre Slottsgate',
#   141: 'Nordre gate',
#   142: 'Norsk Folkemuseum',
#   143: 'Nydalen',
#   144: 'Nylandsveien',
#   145: 'Olaf Ryes plass',
#   146: 'Olav Vs gate',
#   147: 'Oscars gate',
#   148: 'Oslo Handelsgymnasium',
#   149: 'Oslo Hospital',
#   150: 'Oslo Plaza',
#   151: 'Over Rådhusgata',
#   152: 'Paléhaven',
#   153: 'Parkveien',
#   154: 'Pilestredet',
#   155: 'Pilestredet 63',
#   156: 'Pilestredet Studenthus',
#   157: 'Riddervoldplass',
#   158: 'Ringnes Park',
#   159: 'Rolf Wickstrøms vei',
#   160: 'Ruseløkkgården',
#   161: 'Rådhusbrygge 4',
#   162: 'Rådhusgata',
#   163: 'Saga Kino',
#   164: 'Sagene bussholdeplass',
#   165: 'Salt',
#   166: 'Schives gate',
#   167: 'Schous plass',
#   168: 'Schous plass trikkestopp',
#   169: 'Sentrum Scene',
#   170: 'Sinsen T-bane',
#   171: 'Sinsenveien',
#   172: 'Sirkustomta',
#   173: 'Sjølyst',
#   174: 'Sjøsiden vest',
#   175: 'Sjøsiden øst',
#   176: 'Skarpsnoparken',
#   177: 'Skillebekk',
#   178: 'Skippergata',
#   179: 'Skovveien',
#   180: 'Skråninga',
#   181: 'Skøyen',
#   182: 'Skøyen Stasjon',
#   183: 'Slemdalsveien',
#   184: 'Slottsparken Øst',
#   185: 'Sofienberggata',
#   186: 'Sofienbergparken nord',
#   187: 'Sofienbergparken nordvest',
#   188: 'Sofienbergparken sør',
#   189: 'Sognsveien',
#   190: 'Sommerfrydhagen',
#   191: 'Sotahjørnet',
#   192: 'Spikersuppa Vest',
#   193: 'Spikersuppa Øst',
#   194: 'St. Hanshaugen',
#   195: 'St. Hanshaugen park nord',
#   196: 'St. Hanshaugen park sør',
#   197: 'St. Hanshaugen park vest',
#   198: 'St. Olavs gate',
#   199: 'Stavangergata',
#   200: 'Stensgata',
#   201: 'Stensparken',
#   202: 'Stockfleths gate',
#   203: 'Storgata',
#   204: 'Storo Storsenter',
#   205: 'Studenterlunden',
#   206: 'Studentparlamentet',
#   207: 'Suhms gate',
#   208: 'Sukkerbiten',
#   209: 'Søndre gate',
#   210: 'Sørvest for Slottsparken',
#   211: 'Tannlegehøyskolen',
#   212: 'Thereses gate',
#   213: 'Thomas Heftyes plass',
#   214: 'Thune',
#   215: 'Tjuvholmen',
#   216: 'Tordenskiolds gate',
#   217: 'Torggata',
#   218: 'Torshovdalen øst',
#   219: 'Torshovparken vest',
#   220: 'Trelastgata',
#   221: 'Trondheimsveien',
#   222: 'Tøyen skole',
#   223: 'Tøyenbekken',
#   224: 'Tøyenparken',
#   225: 'Tåsen Senter',
#   226: 'Tåsenløkka',
#   227: 'Uelands gate',
#   228: 'Ullevål sykehus',
#   229: 'Ullevålsalléen',
#   230: 'Ullevålsveien',
#   231: 'Uranienborgparken',
#   232: 'Uranienborgveien',
#   233: 'Valkyrieplassen',
#   234: 'Vaterlandsparken',
#   235: 'Vaterlandsparken II',
#   236: 'Vestkanttorvet',
#   237: 'Vippetangen vest',
#   238: 'Vippetangen øst',
#   239: 'Volvat',
#   240: 'Vulkan',
#   241: 'Vålerenga',
#   242: 'Vår Frelsers gravlund sør',
#   243: 'Økernveien',
#   244: 'Totalsum',
#   245: nan,
#   246: nan,
#   247: nan,
#   248: nan,
#   249: nan,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  'c_may': {0: 'Antall av ended_at',
#   1: 1879,
#   2: 904,
#   3: 2331,
#   4: 3116,
#   5: 4306,
#   6: 1579,
#   7: 1212,
#   8: 887,
#   9: 1792,
#   10: 1176,
#   11: 602,
#   12: 409,
#   13: 391,
#   14: 245,
#   15: 3142,
#   16: 955,
#   17: 1881,
#   18: 764,
#   19: 2841,
#   20: 1262,
#   21: 3361,
#   22: 782,
#   23: 2177,
#   24: 1136,
#   25: 357,
#   26: 818,
#   27: 479,
#   28: 3738,
#   29: 258,
#   30: 2924,
#   31: 2398,
#   32: 1046,
#   33: 1244,
#   34: 869,
#   35: 143,
#   36: 718,
#   37: 167,
#   38: 1646,
#   39: 1196,
#   40: 840,
#   41: 986,
#   42: 391,
#   43: 304,
#   44: 1711,
#   45: 1206,
#   46: 987,
#   47: 1712,
#   48: 343,
#   49: 388,
#   50: 272,
#   51: 1812,
#   52: 2242,
#   53: 657,
#   54: 241,
#   55: 1489,
#   56: 1788,
#   57: 2100,
#   58: 330,
#   59: 1611,
#   60: 929,
#   61: 489,
#   62: 620,
#   63: 1544,
#   64: 884,
#   65: 214,
#   66: 138,
#   67: 286,
#   68: 445,
#   69: 1007,
#   70: 156,
#   71: 491,
#   72: 1277,
#   73: 168,
#   74: 721,
#   75: 1491,
#   76: 1731,
#   77: 1485,
#   78: 1178,
#   79: 1948,
#   80: 612,
#   81: 135,
#   82: 465,
#   83: 150,
#   84: 1112,
#   85: 1118,
#   86: 4086,
#   87: 1512,
#   88: 214,
#   89: 1663,
#   90: 664,
#   91: 453,
#   92: 1643,
#   93: 1984,
#   94: 750,
#   95: 1018,
#   96: 598,
#   97: 563,
#   98: 3194,
#   99: 132,
#   100: 803,
#   101: 2314,
#   102: 3278,
#   103: 2262,
#   104: 407,
#   105: 722,
#   106: 174,
#   107: 1925,
#   108: 871,
#   109: 1973,
#   110: 435,
#   111: 559,
#   112: 1281,
#   113: 711,
#   114: 1691,
#   115: 460,
#   116: 2015,
#   117: 976,
#   118: 629,
#   119: 1640,
#   120: 909,
#   121: 886,
#   122: 197,
#   123: 419,
#   124: 387,
#   125: 232,
#   126: 648,
#   127: 2087,
#   128: 283,
#   129: 950,
#   130: 1259,
#   131: 583,
#   132: 673,
#   133: 429,
#   134: 258,
#   135: 760,
#   136: 2085,
#   137: 1112,
#   138: 1325,
#   139: 1784,
#   140: 1086,
#   141: 1458,
#   142: 765,
#   143: 125,
#   144: 1646,
#   145: 4062,
#   146: 1596,
#   147: 550,
#   148: 1426,
#   149: 1248,
#   150: 1195,
#   151: 1055,
#   152: 3364,
#   153: 1991,
#   154: 906,
#   155: 1400,
#   156: 1044,
#   157: 809,
#   158: 4298,
#   159: 39,
#   160: 1241,
#   161: 6339,
#   162: 1018,
#   163: 2305,
#   164: 929,
#   165: 913,
#   166: 872,
#   167: 3516,
#   168: 2029,
#   169: 4718,
#   170: 311,
#   171: 311,
#   172: 928,
#   173: 528,
#   174: 2981,
#   175: 4213,
#   176: 326,
#   177: 1623,
#   178: 983,
#   179: 1191,
#   180: 1952,
#   181: 1450,
#   182: 475,
#   183: 1169,
#   184: 1205,
#   185: 1288,
#   186: 2413,
#   187: 2300,
#   188: 1354,
#   189: 519,
#   190: 1659,
#   191: 524,
#   192: 4083,
#   193: 2300,
#   194: 1454,
#   195: 721,
#   196: 719,
#   197: 861,
#   198: 2772,
#   199: 826,
#   200: 1177,
#   201: 1282,
#   202: 504,
#   203: 1587,
#   204: 757,
#   205: 2073,
#   206: 1146,
#   207: 912,
#   208: 1637,
#   209: 2404,
#   210: 373,
#   211: 522,
#   212: 517,
#   213: 1846,
#   214: 1204,
#   215: 3767,
#   216: 589,
#   217: 5687,
#   218: 379,
#   219: 291,
#   220: 1319,
#   221: 764,
#   222: 3203,
#   223: 2297,
#   224: 757,
#   225: 201,
#   226: 407,
#   227: 789,
#   228: 867,
#   229: 191,
#   230: 477,
#   231: 662,
#   232: 1984,
#   233: 1039,
#   234: 2610,
#   235: 840,
#   236: 831,
#   237: 1608,
#   238: 688,
#   239: 281,
#   240: 2319,
#   241: 525,
#   242: 2978,
#   243: 315,
#   244: 314189,
#   245: nan,
#   246: nan,
#   247: nan,
#   248: nan,
#   249: nan,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  '06': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Nord',
#   10: 'Arkaden Sør',
#   11: 'Arkitekt Rivertz Plass',
#   12: 'Badebakken',
#   13: 'Bak Niels Treschows hus nord',
#   14: 'Bak Niels Treschows hus sør',
#   15: 'Bankplassen',
#   16: 'Bentsebrugata',
#   17: 'Bernt Ankers gate',
#   18: 'BI Nydalen',
#   19: 'Birkelunden',
#   20: "Biskop Gunnerus' gate",
#   21: 'Bislett Stadion',
#   22: 'Bislettgata',
#   23: 'Bjerregaards gate',
#   24: 'Bjerregaardsgate Øst',
#   25: 'Bjølsen mølle',
#   26: 'Bjølsen Studentby',
#   27: 'Bjølsendumpa',
#   28: 'Bjørvika',
#   29: 'Blindern studentparkering',
#   30: 'Bogstadveien',
#   31: 'Botanisk Hage sør',
#   32: 'Botanisk hage sør-vest',
#   33: 'Botanisk Hage vest',
#   34: 'Briskeby',
#   35: 'Bryn T-Bane',
#   36: 'Bygdøy allé',
#   37: 'Bøkkerveien',
#   38: 'Carl Berners plass sør',
#   39: 'Chr. Michelsens Gate',
#   40: 'Colbjørnsens gate',
#   41: 'Colletts gate',
#   42: 'Colosseum Kino',
#   43: 'Det Teologiske fakultet',
#   44: 'Diakonhjemmet',
#   45: 'Dokkveien',
#   46: 'Drammensveien',
#   47: 'Dyvekes bru',
#   48: 'Dælenenggata',
#   49: 'Edvard Storms gate',
#   50: 'Elisenberg',
#   51: 'Enerhaugen',
#   52: 'Ensjø T-Bane',
#   53: 'Ensjøveien',
#   54: 'Fagerheimgata',
#   55: 'Filipstadveien',
#   56: 'Finnmarksgata',
#   57: 'Forskningsveien',
#   58: 'Fram-gården',
#   59: 'Fred Olsens gate',
#   60: 'Fredensborg',
#   61: 'Friggfeltet',
#   62: 'Frogner plass',
#   63: 'Frogner Stadion',
#   64: 'Frogner Tennisklubb',
#   65: 'Frognerbadet',
#   66: 'Frognerstranda',
#   67: 'Frognerveien',
#   68: 'Frøen T-bane',
#   69: 'Furulund',
#   70: 'Fyrstikktorget',
#   71: 'Fysikkbygningen',
#   72: 'Galgeberg',
#   73: 'Gaustad T-bane',
#   74: 'Georg Morgenstiernes hus',
#   75: 'Gimle Kino',
#   76: 'Goethe Institut',
#   77: 'Grenseveien',
#   78: 'Griffenfeldts gate',
#   79: 'Grünerhagen Nord',
#   80: 'Grønlands torg',
#   81: 'Hallénparken',
#   82: 'Hallings gate',
#   83: 'Hammersborg Torg',
#   84: 'Hans Nielsen Hauges plass',
#   85: 'Hasle',
#   86: 'Hasle Torg',
#   87: 'HasleLinje',
#   88: 'Hausmanns bru',
#   89: 'Hausmanns gate',
#   90: 'Helga Helgesens plass',
#   91: 'Henrik Ibsens gate',
#   92: 'Henrik Wergelands allé',
#   93: 'HiOA',
#   94: 'Hoff terrasse holdeplass',
#   95: 'Hoffsveien',
#   96: 'Holbergs Plass',
#   97: 'Huitfeldts gate',
#   98: 'Huk',
#   99: 'Hydroparken',
#   100: 'Idioten',
#   101: 'Ila',
#   102: 'Jakob kirke',
#   103: 'Jarlsborgveien',
#   104: 'Jenny Braatens Plass',
#   105: 'Jens Bjelkes gate',
#   106: 'Jernbanetorget',
#   107: 'Jess Carlsens gate',
#   108: 'John Colletts plass',
#   109: 'Jordalgata',
#   110: 'Kampen park Øst',
#   111: 'Karenlyst allé',
#   112: 'Kirkegata 15',
#   113: 'Kirkeristen',
#   114: 'Kirkeveien',
#   115: 'Kjeld Stubs gate',
#   116: 'Kontraskjæret',
#   117: "Krebs' gate",
#   118: 'Kværnerbyen',
#   119: 'Københavngata busstopp',
#   120: 'Lakkegata',
#   121: 'Landstads gate',
#   122: 'Langkaia',
#   123: 'Lille Grensen',
#   124: 'Lilleborgbanen',
#   125: 'Linaaes gate',
#   126: 'Lindern',
#   127: 'Lodalen busstopp',
#   128: 'Lørenveien',
#   129: 'Mailundveien',
#   130: 'Majorstua skole',
#   131: 'Majorstuen',
#   132: 'Majorstuen t-bane',
#   133: 'Majorstuveien',
#   134: 'Mandalls gate',
#   135: 'Marcus Thranes gate',
#   136: 'Marienlyst',
#   137: 'Marienlystparken',
#   138: 'Meltzers gate',
#   139: 'Monolittveien',
#   140: 'Munkedamsveien',
#   141: 'Munkegata trikkestopp',
#   142: 'Myraløkka Øst',
#   143: 'Mølleparken',
#   144: 'Møllergata',
#   145: 'Nedre Slottsgate',
#   146: 'Nordre gate',
#   147: 'Norsk Folkemuseum',
#   148: 'Nydalen',
#   149: 'Nylandsveien',
#   150: 'Olaf Ryes plass',
#   151: 'Olav Vs gate',
#   152: 'Oscars gate',
#   153: 'Oslo Handelsgymnasium',
#   154: 'Oslo Hospital',
#   155: 'Oslo Plaza',
#   156: 'Over Rådhusgata',
#   157: 'Paléhaven',
#   158: 'Parkveien',
#   159: 'Pilestredet',
#   160: 'Pilestredet 63',
#   161: 'Pilestredet Studenthus',
#   162: 'Riddervoldplass',
#   163: 'Ringnes Park',
#   164: 'Rolf Wickstrøms vei',
#   165: 'Ruseløkkgården',
#   166: 'Rådhusbrygge 4',
#   167: 'Rådhusgata',
#   168: 'Saga Kino',
#   169: 'Sagene bussholdeplass',
#   170: 'Salt',
#   171: 'Schives gate',
#   172: 'Schous plass',
#   173: 'Schous plass trikkestopp',
#   174: 'Sentrum Scene',
#   175: 'Sinsen T-bane',
#   176: 'Sinsenveien',
#   177: 'Sirkustomta',
#   178: 'Sjølyst',
#   179: 'Sjøsiden vest',
#   180: 'Sjøsiden øst',
#   181: 'Skarpsnoparken',
#   182: 'Skillebekk',
#   183: 'Skippergata',
#   184: 'Skovveien',
#   185: 'Skråninga',
#   186: 'Skøyen',
#   187: 'Skøyen Stasjon',
#   188: 'Slemdalsveien',
#   189: 'Slottsparken Øst',
#   190: 'Sofienberggata',
#   191: 'Sofienbergparken nord',
#   192: 'Sofienbergparken nordvest',
#   193: 'Sofienbergparken sør',
#   194: 'Sognsveien',
#   195: 'Sommerfrydhagen',
#   196: 'Sotahjørnet',
#   197: 'Spikersuppa Vest',
#   198: 'Spikersuppa Øst',
#   199: 'St. Hanshaugen',
#   200: 'St. Hanshaugen park nord',
#   201: 'St. Hanshaugen park sør',
#   202: 'St. Hanshaugen park vest',
#   203: 'St. Olavs gate',
#   204: 'Stavangergata',
#   205: 'Stensgata',
#   206: 'Stensparken',
#   207: 'Stockfleths gate',
#   208: 'Storgata',
#   209: 'Storo Storsenter',
#   210: 'Studenterlunden',
#   211: 'Studentparlamentet',
#   212: 'Suhms gate',
#   213: 'Søndre gate',
#   214: 'Tannlegehøyskolen',
#   215: 'Thereses gate',
#   216: 'Thomas Heftyes plass',
#   217: 'Thune',
#   218: 'Tjuvholmen',
#   219: 'Tordenskiolds gate',
#   220: 'Torggata',
#   221: 'Torshovdalen øst',
#   222: 'Torshovparken vest',
#   223: 'Trelastgata',
#   224: 'Trondheimsveien',
#   225: 'Tøyen skole',
#   226: 'Tøyenbekken',
#   227: 'Tøyenparken',
#   228: 'Tåsen Senter',
#   229: 'Tåsenløkka',
#   230: 'Uelands gate',
#   231: 'Ullevål sykehus',
#   232: 'Ullevålsalléen',
#   233: 'Ullevålsveien',
#   234: 'Uranienborgparken',
#   235: 'Uranienborgveien',
#   236: 'Valkyrieplassen',
#   237: 'Vaterlandsparken',
#   238: 'Vaterlandsparken II',
#   239: 'Vestkanttorvet',
#   240: 'Vippetangen vest',
#   241: 'Vippetangen øst',
#   242: 'Volvat',
#   243: 'Vulkan',
#   244: 'Vålerenga',
#   245: 'Vår Frelsers gravlund sør',
#   246: 'Økernveien',
#   247: 'Totalsum',
#   248: nan,
#   249: nan,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  'c_jun': {0: 'Antall av ended_at',
#   1: 1943,
#   2: 825,
#   3: 2244,
#   4: 3021,
#   5: 4198,
#   6: 1909,
#   7: 1350,
#   8: 835,
#   9: 370,
#   10: 167,
#   11: 605,
#   12: 397,
#   13: 365,
#   14: 171,
#   15: 3854,
#   16: 961,
#   17: 1935,
#   18: 781,
#   19: 3097,
#   20: 1381,
#   21: 2787,
#   22: 1258,
#   23: 2126,
#   24: 1208,
#   25: 363,
#   26: 806,
#   27: 471,
#   28: 4418,
#   29: 242,
#   30: 2518,
#   31: 2421,
#   32: 971,
#   33: 1240,
#   34: 883,
#   35: 196,
#   36: 804,
#   37: 167,
#   38: 1768,
#   39: 1159,
#   40: 821,
#   41: 30,
#   42: 932,
#   43: 422,
#   44: 278,
#   45: 1936,
#   46: 188,
#   47: 1415,
#   48: 916,
#   49: 1719,
#   50: 1185,
#   51: 248,
#   52: 525,
#   53: 274,
#   54: 1919,
#   55: 2536,
#   56: 676,
#   57: 243,
#   58: 1605,
#   59: 1874,
#   60: 2135,
#   61: 294,
#   62: 1457,
#   63: 1003,
#   64: 667,
#   65: 690,
#   66: 1903,
#   67: 881,
#   68: 209,
#   69: 204,
#   70: 299,
#   71: 316,
#   72: 958,
#   73: 113,
#   74: 349,
#   75: 1290,
#   76: 156,
#   77: 143,
#   78: 650,
#   79: 1549,
#   80: 1876,
#   81: 1464,
#   82: 1042,
#   83: 2136,
#   84: 699,
#   85: 136,
#   86: 450,
#   87: 155,
#   88: 1011,
#   89: 927,
#   90: 3914,
#   91: 1852,
#   92: 897,
#   93: 1335,
#   94: 711,
#   95: 586,
#   96: 1538,
#   97: 1924,
#   98: 1273,
#   99: 1033,
#   100: 471,
#   101: 539,
#   102: 3532,
#   103: 134,
#   104: 879,
#   105: 2149,
#   106: 3146,
#   107: 2217,
#   108: 305,
#   109: 762,
#   110: 256,
#   111: 2168,
#   112: 881,
#   113: 2569,
#   114: 295,
#   115: 789,
#   116: 1593,
#   117: 647,
#   118: 1841,
#   119: 480,
#   120: 2120,
#   121: 1024,
#   122: 750,
#   123: 1779,
#   124: 949,
#   125: 964,
#   126: 220,
#   127: 475,
#   128: 444,
#   129: 216,
#   130: 793,
#   131: 2182,
#   132: 233,
#   133: 967,
#   134: 1273,
#   135: 105,
#   136: 514,
#   137: 780,
#   138: 428,
#   139: 69,
#   140: 764,
#   141: 2077,
#   142: 1038,
#   143: 1588,
#   144: 1496,
#   145: 1346,
#   146: 1558,
#   147: 965,
#   148: 151,
#   149: 1739,
#   150: 4432,
#   151: 1835,
#   152: 973,
#   153: 1349,
#   154: 1352,
#   155: 1232,
#   156: 1289,
#   157: 4148,
#   158: 1824,
#   159: 728,
#   160: 1091,
#   161: 858,
#   162: 748,
#   163: 4226,
#   164: 38,
#   165: 1406,
#   166: 7173,
#   167: 1679,
#   168: 2472,
#   169: 920,
#   170: 1059,
#   171: 780,
#   172: 3601,
#   173: 2172,
#   174: 6249,
#   175: 263,
#   176: 313,
#   177: 914,
#   178: 614,
#   179: 4655,
#   180: 3984,
#   181: 121,
#   182: 1700,
#   183: 1032,
#   184: 1447,
#   185: 1754,
#   186: 1720,
#   187: 536,
#   188: 1027,
#   189: 1058,
#   190: 1287,
#   191: 2516,
#   192: 2287,
#   193: 1629,
#   194: 555,
#   195: 1646,
#   196: 525,
#   197: 2863,
#   198: 1605,
#   199: 1394,
#   200: 647,
#   201: 848,
#   202: 818,
#   203: 2697,
#   204: 838,
#   205: 1066,
#   206: 1370,
#   207: 472,
#   208: 1746,
#   209: 749,
#   210: 3584,
#   211: 902,
#   212: 695,
#   213: 882,
#   214: 484,
#   215: 567,
#   216: 1618,
#   217: 1316,
#   218: 4939,
#   219: 686,
#   220: 5138,
#   221: 309,
#   222: 303,
#   223: 1554,
#   224: 969,
#   225: 3279,
#   226: 2583,
#   227: 851,
#   228: 189,
#   229: 474,
#   230: 799,
#   231: 914,
#   232: 212,
#   233: 462,
#   234: 700,
#   235: 2125,
#   236: 814,
#   237: 3099,
#   238: 822,
#   239: 862,
#   240: 1601,
#   241: 790,
#   242: 293,
#   243: 2455,
#   244: 566,
#   245: 2948,
#   246: 339,
#   247: 324295,
#   248: nan,
#   249: nan,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  '07': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Sør',
#   10: 'Arkitekt Rivertz Plass',
#   11: 'Badebakken',
#   12: 'Bak Niels Treschows hus nord',
#   13: 'Bak Niels Treschows hus sør',
#   14: 'Bankplassen',
#   15: 'Bentsebrugata',
#   16: 'Bernt Ankers gate',
#   17: 'BI Nydalen',
#   18: 'Birkelunden',
#   19: "Biskop Gunnerus' gate",
#   20: 'Bislett Stadion',
#   21: 'Bislettgata',
#   22: 'Bjerregaards gate',
#   23: 'Bjerregaardsgate Øst',
#   24: 'Bjølsen mølle',
#   25: 'Bjølsen Studentby',
#   26: 'Bjølsendumpa',
#   27: 'Bjørvika',
#   28: 'Blindern studentparkering',
#   29: 'Bogstadveien',
#   30: 'Borgenveien',
#   31: 'Botanisk Hage sør',
#   32: 'Botanisk hage sør-vest',
#   33: 'Botanisk Hage vest',
#   34: 'Briskeby',
#   35: 'Brugata',
#   36: 'Bryn T-Bane',
#   37: 'Bygdøy allé',
#   38: 'Bøkkerveien',
#   39: 'Carl Berners plass sør',
#   40: 'Chr. Michelsens Gate',
#   41: 'Colbjørnsens gate',
#   42: 'Colletts gate',
#   43: 'Colosseum Kino',
#   44: 'Det Teologiske fakultet',
#   45: 'Diakonhjemmet',
#   46: 'Dokkveien',
#   47: 'Drammensveien',
#   48: 'Dronningens gate',
#   49: 'Dyvekes bru',
#   50: 'Dælenenggata',
#   51: 'Edvard Storms gate',
#   52: 'Elisenberg',
#   53: 'Enerhaugen',
#   54: 'Ensjø T-Bane',
#   55: 'Ensjøveien',
#   56: 'Fagerheimgata',
#   57: 'Filipstadveien',
#   58: 'Finnmarksgata',
#   59: 'Forskningsveien',
#   60: 'Fram-gården',
#   61: 'Fred Olsens gate',
#   62: 'Fredensborg',
#   63: 'Friggfeltet',
#   64: 'Frogner plass',
#   65: 'Frogner Stadion',
#   66: 'Frogner Tennisklubb',
#   67: 'Frognerbadet',
#   68: 'Frognerstranda',
#   69: 'Frognerveien',
#   70: 'Frøen T-bane',
#   71: 'Furulund',
#   72: 'Fyrstikktorget',
#   73: 'Fysikkbygningen',
#   74: 'Galgeberg',
#   75: 'Gaustad T-bane',
#   76: 'Georg Morgenstiernes hus',
#   77: 'Gimle Kino',
#   78: 'Grenseveien',
#   79: 'Griffenfeldts gate',
#   80: 'Grünerhagen Nord',
#   81: 'Grønlands torg',
#   82: 'Hallénparken',
#   83: 'Hallings gate',
#   84: 'Hammersborg Torg',
#   85: 'Hans Nielsen Hauges plass',
#   86: 'Hasle',
#   87: 'Hasle Torg',
#   88: 'HasleLinje',
#   89: 'Hausmanns bru',
#   90: 'Hausmanns gate',
#   91: 'Helga Helgesens plass',
#   92: 'Henrik Ibsens gate',
#   93: 'Henrik Wergelands allé',
#   94: 'HiOA',
#   95: 'Hoff terrasse holdeplass',
#   96: 'Hoffsveien',
#   97: 'Holbergs Plass',
#   98: 'Huitfeldts gate',
#   99: 'Huk',
#   100: 'Hydroparken',
#   101: 'Idioten',
#   102: 'Ila',
#   103: 'Jakob kirke',
#   104: 'Jarlsborgveien',
#   105: 'Jenny Braatens Plass',
#   106: 'Jens Bjelkes gate',
#   107: 'Jernbanetorget',
#   108: 'Jess Carlsens gate',
#   109: 'John Colletts plass',
#   110: 'Jordalgata',
#   111: 'Kampen park Øst',
#   112: 'Karenlyst allé',
#   113: 'Kirkegata 15',
#   114: 'Kirkeristen',
#   115: 'Kirkeveien',
#   116: 'Kjeld Stubs gate',
#   117: 'Kontraskjæret',
#   118: "Krebs' gate",
#   119: 'Kværnerbyen',
#   120: 'Københavngata busstopp',
#   121: 'Lakkegata',
#   122: 'Landstads gate',
#   123: 'Langkaia',
#   124: 'Lille Grensen',
#   125: 'Lilleborgbanen',
#   126: 'Linaaes gate',
#   127: 'Lindern',
#   128: 'Lodalen busstopp',
#   129: 'Lørenveien',
#   130: 'Mailundveien',
#   131: 'Majorstua skole',
#   132: 'Majorstuen',
#   133: 'Majorstuen t-bane',
#   134: 'Majorstuveien',
#   135: 'Mandalls gate',
#   136: 'Marcus Thranes gate',
#   137: 'Marienlyst',
#   138: 'Marienlystparken',
#   139: 'Meltzers gate',
#   140: 'Monolittveien',
#   141: 'Munkedamsveien',
#   142: 'Munkegata trikkestopp',
#   143: 'Myraløkka Øst',
#   144: 'Mølleparken',
#   145: 'Møllergata',
#   146: 'Nedre Slottsgate',
#   147: 'Nordre gate',
#   148: 'Norsk Folkemuseum',
#   149: 'Nydalen',
#   150: 'Nylandsveien',
#   151: 'Olaf Ryes plass',
#   152: 'Olav Vs gate',
#   153: 'Oscars gate',
#   154: 'Oslo Handelsgymnasium',
#   155: 'Oslo Hospital',
#   156: 'Oslo Plaza',
#   157: 'Over Rådhusgata',
#   158: 'Paléhaven',
#   159: 'Parkveien',
#   160: 'Pilestredet',
#   161: 'Pilestredet 63',
#   162: 'Pilestredet Studenthus',
#   163: 'Riddervoldplass',
#   164: 'Ringnes Park',
#   165: 'Rolf Wickstrøms vei',
#   166: 'Ruseløkkgården',
#   167: 'Rådhusbrygge 4',
#   168: 'Rådhusgata',
#   169: 'Saga Kino',
#   170: 'Sagene bussholdeplass',
#   171: 'Salt',
#   172: 'Schives gate',
#   173: 'Schous plass',
#   174: 'Schous plass trikkestopp',
#   175: 'Sentrum Scene',
#   176: 'Sinsen T-bane',
#   177: 'Sinsenveien',
#   178: 'Sirkustomta',
#   179: 'Sjølyst',
#   180: 'Sjøsiden vest',
#   181: 'Sjøsiden øst',
#   182: 'Skarpsnoparken',
#   183: 'Skillebekk',
#   184: 'Skippergata',
#   185: 'Skovveien',
#   186: 'Skråninga',
#   187: 'Skøyen',
#   188: 'Skøyen Stasjon',
#   189: 'Slemdalsveien',
#   190: 'Slottsparken Øst',
#   191: 'Sofienberggata',
#   192: 'Sofienbergparken nord',
#   193: 'Sofienbergparken nordvest',
#   194: 'Sofienbergparken sør',
#   195: 'Sognsveien',
#   196: 'Sommerfrydhagen',
#   197: 'Sotahjørnet',
#   198: 'Spikersuppa Vest',
#   199: 'Spikersuppa Øst',
#   200: 'St. Hanshaugen',
#   201: 'St. Hanshaugen park nord',
#   202: 'St. Hanshaugen park sør',
#   203: 'St. Hanshaugen park vest',
#   204: 'St. Olavs gate',
#   205: 'Stavangergata',
#   206: 'Stensgata',
#   207: 'Stensparken',
#   208: 'Stockfleths gate',
#   209: 'Storgata',
#   210: 'Storo Storsenter',
#   211: 'Studenterlunden',
#   212: 'Studentparlamentet',
#   213: 'Suhms gate',
#   214: 'Sukkerbiten',
#   215: 'Søndre gate',
#   216: 'Sørvest for Slottsparken',
#   217: 'Tannlegehøyskolen',
#   218: 'Thereses gate',
#   219: 'Thomas Heftyes plass',
#   220: 'Thune',
#   221: 'Tjuvholmen',
#   222: 'Tordenskiolds gate',
#   223: 'Torggata',
#   224: 'Torshovdalen øst',
#   225: 'Torshovparken vest',
#   226: 'Trelastgata',
#   227: 'Trondheimsveien',
#   228: 'Tøyen skole',
#   229: 'Tøyenbekken',
#   230: 'Tøyenparken',
#   231: 'Tåsen Senter',
#   232: 'Tåsenløkka',
#   233: 'Uelands gate',
#   234: 'Ullevål sykehus',
#   235: 'Ullevålsalléen',
#   236: 'Ullevålsveien',
#   237: 'Uranienborgparken',
#   238: 'Uranienborgveien',
#   239: 'Valkyrieplassen',
#   240: 'Vaterlandsparken',
#   241: 'Vaterlandsparken II',
#   242: 'Vestkanttorvet',
#   243: 'Vippetangen vest',
#   244: 'Vippetangen øst',
#   245: 'Volvat',
#   246: 'Vulkan',
#   247: 'Vålerenga',
#   248: 'Vår Frelsers gravlund sør',
#   249: 'Økernveien',
#   250: 'Totalsum',
#   251: nan,
#   252: nan,
#   253: nan},
#  'c_july': {0: 'Antall av ended_at',
#   1: 1565,
#   2: 671,
#   3: 1865,
#   4: 2617,
#   5: 3600,
#   6: 2142,
#   7: 1217,
#   8: 904,
#   9: 1994,
#   10: 624,
#   11: 498,
#   12: 304,
#   13: 143,
#   14: 2229,
#   15: 925,
#   16: 2176,
#   17: 1060,
#   18: 2195,
#   19: 1394,
#   20: 2485,
#   21: 1583,
#   22: 1779,
#   23: 1001,
#   24: 437,
#   25: 880,
#   26: 567,
#   27: 3688,
#   28: 202,
#   29: 2209,
#   30: 77,
#   31: 2330,
#   32: 872,
#   33: 960,
#   34: 702,
#   35: 21,
#   36: 206,
#   37: 808,
#   38: 183,
#   39: 1578,
#   40: 1113,
#   41: 649,
#   42: 304,
#   43: 869,
#   44: 336,
#   45: 318,
#   46: 1876,
#   47: 633,
#   48: 619,
#   49: 1250,
#   50: 995,
#   51: 1277,
#   52: 1041,
#   53: 455,
#   54: 484,
#   55: 350,
#   56: 1702,
#   57: 3092,
#   58: 591,
#   59: 199,
#   60: 1289,
#   61: 2235,
#   62: 1814,
#   63: 200,
#   64: 1684,
#   65: 963,
#   66: 957,
#   67: 941,
#   68: 2034,
#   69: 694,
#   70: 240,
#   71: 170,
#   72: 253,
#   73: 232,
#   74: 804,
#   75: 98,
#   76: 244,
#   77: 1097,
#   78: 120,
#   79: 443,
#   80: 1276,
#   81: 1916,
#   82: 934,
#   83: 787,
#   84: 1840,
#   85: 717,
#   86: 187,
#   87: 537,
#   88: 140,
#   89: 910,
#   90: 755,
#   91: 3632,
#   92: 1401,
#   93: 937,
#   94: 1139,
#   95: 605,
#   96: 555,
#   97: 1286,
#   98: 1567,
#   99: 2836,
#   100: 893,
#   101: 409,
#   102: 431,
#   103: 2550,
#   104: 75,
#   105: 819,
#   106: 2091,
#   107: 2670,
#   108: 1567,
#   109: 237,
#   110: 637,
#   111: 207,
#   112: 2233,
#   113: 919,
#   114: 3095,
#   115: 291,
#   116: 526,
#   117: 1347,
#   118: 607,
#   119: 1853,
#   120: 525,
#   121: 1821,
#   122: 1031,
#   123: 837,
#   124: 1487,
#   125: 845,
#   126: 1370,
#   127: 232,
#   128: 320,
#   129: 485,
#   130: 200,
#   131: 902,
#   132: 2018,
#   133: 270,
#   134: 765,
#   135: 1214,
#   136: 947,
#   137: 385,
#   138: 752,
#   139: 396,
#   140: 220,
#   141: 505,
#   142: 2067,
#   143: 1100,
#   144: 1324,
#   145: 1495,
#   146: 1079,
#   147: 1419,
#   148: 1323,
#   149: 231,
#   150: 1490,
#   151: 4725,
#   152: 2080,
#   153: 1667,
#   154: 1189,
#   155: 1335,
#   156: 1151,
#   157: 1200,
#   158: 4091,
#   159: 1525,
#   160: 604,
#   161: 841,
#   162: 577,
#   163: 626,
#   164: 3930,
#   165: 62,
#   166: 939,
#   167: 8329,
#   168: 1783,
#   169: 1932,
#   170: 881,
#   171: 1431,
#   172: 616,
#   173: 3181,
#   174: 1736,
#   175: 4946,
#   176: 321,
#   177: 333,
#   178: 903,
#   179: 702,
#   180: 2871,
#   181: 3633,
#   182: 254,
#   183: 1528,
#   184: 1189,
#   185: 1167,
#   186: 1808,
#   187: 1589,
#   188: 487,
#   189: 746,
#   190: 1454,
#   191: 1129,
#   192: 2026,
#   193: 2168,
#   194: 1307,
#   195: 525,
#   196: 1452,
#   197: 486,
#   198: 3773,
#   199: 2514,
#   200: 1227,
#   201: 468,
#   202: 667,
#   203: 714,
#   204: 2233,
#   205: 671,
#   206: 896,
#   207: 1133,
#   208: 348,
#   209: 1565,
#   210: 1134,
#   211: 1643,
#   212: 744,
#   213: 636,
#   214: 4435,
#   215: 2160,
#   216: 268,
#   217: 441,
#   218: 464,
#   219: 1415,
#   220: 1019,
#   221: 4751,
#   222: 878,
#   223: 4761,
#   224: 361,
#   225: 287,
#   226: 1431,
#   227: 916,
#   228: 2953,
#   229: 2422,
#   230: 849,
#   231: 220,
#   232: 471,
#   233: 697,
#   234: 1068,
#   235: 222,
#   236: 436,
#   237: 518,
#   238: 1631,
#   239: 589,
#   240: 3586,
#   241: 998,
#   242: 779,
#   243: 1753,
#   244: 814,
#   245: 285,
#   246: 2289,
#   247: 528,
#   248: 2312,
#   249: 302,
#   250: 310955,
#   251: nan,
#   252: nan,
#   253: nan},
#  '08': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Nord',
#   10: 'Arkaden Sør',
#   11: 'Arkitekt Rivertz Plass',
#   12: 'Badebakken',
#   13: 'Bak Niels Treschows hus nord',
#   14: 'Bak Niels Treschows hus sør',
#   15: 'Bankplassen',
#   16: 'Bentsebrugata',
#   17: 'Bernt Ankers gate',
#   18: 'BI Nydalen',
#   19: 'Birkelunden',
#   20: "Biskop Gunnerus' gate",
#   21: 'Bislett Stadion',
#   22: 'Bislettgata',
#   23: 'Bjerregaards gate',
#   24: 'Bjerregaardsgate Øst',
#   25: 'Bjølsen mølle',
#   26: 'Bjølsen Studentby',
#   27: 'Bjølsendumpa',
#   28: 'Bjørvika',
#   29: 'Blindern studentparkering',
#   30: 'Bogstadveien',
#   31: 'Borgenveien',
#   32: 'Botanisk Hage sør',
#   33: 'Botanisk hage sør-vest',
#   34: 'Botanisk Hage vest',
#   35: 'Briskeby',
#   36: 'Brugata',
#   37: 'Bryn T-Bane',
#   38: 'Brynseng T-bane',
#   39: 'Bygdøy allé',
#   40: 'Bøkkerveien',
#   41: 'Carl Berners plass sør',
#   42: 'Chr. Michelsens Gate',
#   43: 'Colbjørnsens gate',
#   44: 'Colletts gate',
#   45: 'Colosseum Kino',
#   46: 'Det Teologiske fakultet',
#   47: 'Diakonhjemmet',
#   48: 'Dokkveien',
#   49: 'Drammensveien',
#   50: 'Dronningens gate',
#   51: 'Dyvekes bru',
#   52: 'Dælenenggata',
#   53: 'Edvard Storms gate',
#   54: 'Elisenberg',
#   55: 'Enerhaugen',
#   56: 'Ensjø T-Bane',
#   57: 'Ensjøveien',
#   58: 'Fagerheimgata',
#   59: 'Filipstadveien',
#   60: 'Finnmarksgata',
#   61: 'Forskningsveien',
#   62: 'Fram-gården',
#   63: 'Fred Olsens gate',
#   64: 'Fredensborg',
#   65: 'Friggfeltet',
#   66: 'Frogner plass',
#   67: 'Frogner Stadion',
#   68: 'Frogner Tennisklubb',
#   69: 'Frognerbadet',
#   70: 'Frognerstranda',
#   71: 'Frognerveien',
#   72: 'Frøen T-bane',
#   73: 'Furulund',
#   74: 'Fyrstikktorget',
#   75: 'Fysikkbygningen',
#   76: 'Galgeberg',
#   77: 'Gaustad T-bane',
#   78: 'Georg Morgenstiernes hus',
#   79: 'Gimle Kino',
#   80: 'Grenseveien',
#   81: 'Griffenfeldts gate',
#   82: 'Grünerhagen Nord',
#   83: 'Grønlands torg',
#   84: 'Hallénparken',
#   85: 'Hallings gate',
#   86: 'Hammersborg Torg',
#   87: 'Hans Nielsen Hauges plass',
#   88: 'Hasle',
#   89: 'Hasle Torg',
#   90: 'HasleLinje',
#   91: 'Hausmanns bru',
#   92: 'Hausmanns gate',
#   93: 'Helga Helgesens plass',
#   94: 'Henrik Ibsens gate',
#   95: 'Henrik Wergelands allé',
#   96: 'HiOA',
#   97: 'Hoff terrasse holdeplass',
#   98: 'Hoffsveien',
#   99: 'Holbergs Plass',
#   100: 'Huitfeldts gate',
#   101: 'Huk',
#   102: 'Hydroparken',
#   103: 'Idioten',
#   104: 'Ila',
#   105: 'Jakob kirke',
#   106: 'Jarlsborgveien',
#   107: 'Jenny Braatens Plass',
#   108: 'Jens Bjelkes gate',
#   109: 'Jernbanetorget',
#   110: 'Jess Carlsens gate',
#   111: 'John Colletts plass',
#   112: 'Jordalgata',
#   113: 'Kampen park Øst',
#   114: 'Karenlyst allé',
#   115: 'Kirkegata 15',
#   116: 'Kirkeristen',
#   117: 'Kirkeveien',
#   118: 'Kjeld Stubs gate',
#   119: 'Kontraskjæret',
#   120: "Krebs' gate",
#   121: 'Kværnerbyen',
#   122: 'Københavngata busstopp',
#   123: 'Lakkegata',
#   124: 'Landstads gate',
#   125: 'Langkaia',
#   126: 'Lille Grensen',
#   127: 'Lilleborgbanen',
#   128: 'Linaaes gate',
#   129: 'Lindern',
#   130: 'Lodalen busstopp',
#   131: 'Lørenveien',
#   132: 'Mailundveien',
#   133: 'Majorstua skole',
#   134: 'Majorstuen',
#   135: 'Majorstuen t-bane',
#   136: 'Majorstuveien',
#   137: 'Mandalls gate',
#   138: 'Marcus Thranes gate',
#   139: 'Marienlyst',
#   140: 'Marienlystparken',
#   141: 'Meltzers gate',
#   142: 'Monolittveien',
#   143: 'Munkedamsveien',
#   144: 'Munkegata trikkestopp',
#   145: 'Myraløkka Øst',
#   146: 'Mølleparken',
#   147: 'Møllergata',
#   148: 'Nedre Slottsgate',
#   149: 'Nordre gate',
#   150: 'Norsk Folkemuseum',
#   151: 'Nydalen',
#   152: 'Nylandsveien',
#   153: 'Olaf Ryes plass',
#   154: 'Olav Vs gate',
#   155: 'Oscars gate',
#   156: 'Oslo Handelsgymnasium',
#   157: 'Oslo Hospital',
#   158: 'Oslo Plaza',
#   159: 'Over Rådhusgata',
#   160: 'Paléhaven',
#   161: 'Parkveien',
#   162: 'Pilestredet',
#   163: 'Pilestredet 63',
#   164: 'Pilestredet Studenthus',
#   165: 'Riddervoldplass',
#   166: 'Ringnes Park',
#   167: 'Rolf Wickstrøms vei',
#   168: 'Ruseløkkgården',
#   169: 'Rådhusbrygge 4',
#   170: 'Rådhusgata',
#   171: 'Saga Kino',
#   172: 'Sagene bussholdeplass',
#   173: 'Salt',
#   174: 'Schives gate',
#   175: 'Schous plass',
#   176: 'Schous plass trikkestopp',
#   177: 'Sentrum Scene',
#   178: 'Sinsen T-bane',
#   179: 'Sinsenveien',
#   180: 'Sirkustomta',
#   181: 'Sjølyst',
#   182: 'Sjøsiden ved fontenen',
#   183: 'Sjøsiden ved trappen',
#   184: 'Sjøsiden vest',
#   185: 'Sjøsiden øst',
#   186: 'Skarpsnoparken',
#   187: 'Skillebekk',
#   188: 'Skippergata',
#   189: 'Skovveien',
#   190: 'Skråninga',
#   191: 'Skøyen',
#   192: 'Skøyen Stasjon',
#   193: 'Slemdalsveien',
#   194: 'Slottsparken Øst',
#   195: 'Sofienberggata',
#   196: 'Sofienbergparken nord',
#   197: 'Sofienbergparken nordvest',
#   198: 'Sofienbergparken sør',
#   199: 'Sognsveien',
#   200: 'Sommerfrydhagen',
#   201: 'Sotahjørnet',
#   202: 'Spikersuppa Vest',
#   203: 'Spikersuppa Øst',
#   204: 'St. Hanshaugen',
#   205: 'St. Hanshaugen park nord',
#   206: 'St. Hanshaugen park sør',
#   207: 'St. Hanshaugen park vest',
#   208: 'St. Olavs gate',
#   209: 'Stavangergata',
#   210: 'Stensgata',
#   211: 'Stensparken',
#   212: 'Stockfleths gate',
#   213: 'Storgata',
#   214: 'Storo Storsenter',
#   215: 'Studenterlunden',
#   216: 'Studentparlamentet',
#   217: 'Suhms gate',
#   218: 'Sukkerbiten',
#   219: 'Søndre gate',
#   220: 'Sørvest for Slottsparken',
#   221: 'Tannlegehøyskolen',
#   222: 'Thereses gate',
#   223: 'Thomas Heftyes plass',
#   224: 'Thune',
#   225: 'Tjuvholmen',
#   226: 'Tordenskiolds gate',
#   227: 'Torggata',
#   228: 'Torshovdalen øst',
#   229: 'Torshovparken vest',
#   230: 'Trelastgata',
#   231: 'Trondheimsveien',
#   232: 'Tøyen skole',
#   233: 'Tøyenbekken',
#   234: 'Tøyenparken',
#   235: 'Tåsen Senter',
#   236: 'Tåsenløkka',
#   237: 'Uelands gate',
#   238: 'Ullevål sykehus',
#   239: 'Ullevålsalléen',
#   240: 'Ullevålsveien',
#   241: 'Uranienborgparken',
#   242: 'Uranienborgveien',
#   243: 'Valkyrieplassen',
#   244: 'Vaterlandsparken',
#   245: 'Vestkanttorvet',
#   246: 'Vippetangen vest',
#   247: 'Vippetangen øst',
#   248: 'Volvat',
#   249: 'Vulkan',
#   250: 'Vålerenga',
#   251: 'Vår Frelsers gravlund sør',
#   252: 'Økernveien',
#   253: 'Totalsum'},
#  'c_aug': {0: 'Antall av ended_at',
#   1: 2622,
#   2: 899,
#   3: 2691,
#   4: 3464,
#   5: 4758,
#   6: 2187,
#   7: 1704,
#   8: 980,
#   9: 71,
#   10: 1453,
#   11: 904,
#   12: 427,
#   13: 426,
#   14: 265,
#   15: 4285,
#   16: 1128,
#   17: 2407,
#   18: 1210,
#   19: 3025,
#   20: 1521,
#   21: 3596,
#   22: 2244,
#   23: 2517,
#   24: 1324,
#   25: 487,
#   26: 1011,
#   27: 631,
#   28: 3979,
#   29: 407,
#   30: 2839,
#   31: 191,
#   32: 4187,
#   33: 1281,
#   34: 943,
#   35: 993,
#   36: 1142,
#   37: 263,
#   38: 74,
#   39: 732,
#   40: 204,
#   41: 1935,
#   42: 1372,
#   43: 962,
#   44: 466,
#   45: 1100,
#   46: 513,
#   47: 353,
#   48: 2181,
#   49: 739,
#   50: 916,
#   51: 1623,
#   52: 1379,
#   53: 1957,
#   54: 1435,
#   55: 831,
#   56: 699,
#   57: 405,
#   58: 2244,
#   59: 3577,
#   60: 1011,
#   61: 262,
#   62: 1755,
#   63: 2030,
#   64: 2446,
#   65: 352,
#   66: 1815,
#   67: 1137,
#   68: 743,
#   69: 907,
#   70: 1859,
#   71: 930,
#   72: 312,
#   73: 151,
#   74: 350,
#   75: 473,
#   76: 1131,
#   77: 59,
#   78: 569,
#   79: 1636,
#   80: 211,
#   81: 621,
#   82: 1613,
#   83: 2092,
#   84: 1248,
#   85: 1236,
#   86: 2451,
#   87: 797,
#   88: 212,
#   89: 623,
#   90: 142,
#   91: 1227,
#   92: 1088,
#   93: 4003,
#   94: 2056,
#   95: 1561,
#   96: 1974,
#   97: 901,
#   98: 708,
#   99: 1771,
#   100: 2119,
#   101: 1504,
#   102: 1145,
#   103: 563,
#   104: 582,
#   105: 3400,
#   106: 118,
#   107: 1070,
#   108: 2486,
#   109: 4058,
#   110: 2582,
#   111: 286,
#   112: 979,
#   113: 333,
#   114: 2527,
#   115: 1209,
#   116: 3382,
#   117: 383,
#   118: 697,
#   119: 1664,
#   120: 712,
#   121: 2078,
#   122: 693,
#   123: 2503,
#   124: 1292,
#   125: 850,
#   126: 2131,
#   127: 988,
#   128: 1705,
#   129: 291,
#   130: 552,
#   131: 457,
#   132: 204,
#   133: 1176,
#   134: 2338,
#   135: 316,
#   136: 1014,
#   137: 1413,
#   138: 1463,
#   139: 602,
#   140: 911,
#   141: 606,
#   142: 253,
#   143: 286,
#   144: 2460,
#   145: 1187,
#   146: 1829,
#   147: 1872,
#   148: 902,
#   149: 1765,
#   150: 1197,
#   151: 238,
#   152: 2270,
#   153: 5270,
#   154: 2403,
#   155: 2211,
#   156: 1654,
#   157: 1527,
#   158: 1509,
#   159: 1534,
#   160: 4038,
#   161: 2000,
#   162: 864,
#   163: 1327,
#   164: 1140,
#   165: 900,
#   166: 5246,
#   167: 80,
#   168: 1452,
#   169: 7783,
#   170: 1882,
#   171: 2474,
#   172: 905,
#   173: 1433,
#   174: 904,
#   175: 4233,
#   176: 2154,
#   177: 7028,
#   178: 327,
#   179: 320,
#   180: 363,
#   181: 752,
#   182: 3329,
#   183: 5228,
#   184: 192,
#   185: 274,
#   186: 500,
#   187: 1730,
#   188: 1313,
#   189: 1597,
#   190: 2214,
#   191: 2025,
#   192: 850,
#   193: 1228,
#   194: 1945,
#   195: 1639,
#   196: 2832,
#   197: 2672,
#   198: 1595,
#   199: 555,
#   200: 1796,
#   201: 189,
#   202: 5632,
#   203: 2778,
#   204: 1716,
#   205: 541,
#   206: 801,
#   207: 1083,
#   208: 3168,
#   209: 885,
#   210: 1199,
#   211: 1534,
#   212: 580,
#   213: 1864,
#   214: 893,
#   215: 2227,
#   216: 1380,
#   217: 896,
#   218: 3760,
#   219: 2881,
#   220: 516,
#   221: 578,
#   222: 622,
#   223: 1867,
#   224: 1326,
#   225: 4731,
#   226: 1050,
#   227: 5543,
#   228: 393,
#   229: 388,
#   230: 1845,
#   231: 1138,
#   232: 4126,
#   233: 3205,
#   234: 1248,
#   235: 200,
#   236: 513,
#   237: 962,
#   238: 1097,
#   239: 238,
#   240: 589,
#   241: 735,
#   242: 2173,
#   243: 640,
#   244: 4072,
#   245: 1032,
#   246: 1982,
#   247: 916,
#   248: 350,
#   249: 2709,
#   250: 1087,
#   251: 3375,
#   252: 527,
#   253: 389270},
#  '09': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Nord',
#   10: 'Arkaden Sør',
#   11: 'Arkitekt Rivertz Plass',
#   12: 'Badebakken',
#   13: 'Bak Niels Treschows hus nord',
#   14: 'Bak Niels Treschows hus sør',
#   15: 'Bankplassen',
#   16: 'Bentsebrugata',
#   17: 'Bernt Ankers gate',
#   18: 'BI Nydalen',
#   19: 'Birkelunden',
#   20: "Biskop Gunnerus' gate",
#   21: 'Bislett Stadion',
#   22: 'Bislettgata',
#   23: 'Bjerregaards gate',
#   24: 'Bjerregaardsgate Øst',
#   25: 'Bjølsen mølle',
#   26: 'Bjølsen Studentby',
#   27: 'Bjølsendumpa',
#   28: 'Bjørvika',
#   29: 'Blindern studentparkering',
#   30: 'Bogstadveien',
#   31: 'Borgenveien',
#   32: 'Botanisk Hage sør',
#   33: 'Botanisk hage sør-vest',
#   34: 'Botanisk Hage vest',
#   35: 'Briskeby',
#   36: 'Brugata',
#   37: 'Brynseng T-bane',
#   38: 'Bygdøy allé',
#   39: 'Bøkkerveien',
#   40: 'Carl Berners plass sør',
#   41: 'Chr. Michelsens Gate',
#   42: 'Colbjørnsens gate',
#   43: 'Colletts gate',
#   44: 'Colosseum Kino',
#   45: 'Det Teologiske fakultet',
#   46: 'Diakonhjemmet',
#   47: 'Dokkveien',
#   48: 'Drammensveien',
#   49: 'Dronningens gate',
#   50: 'Dyvekes bru',
#   51: 'Dælenenggata',
#   52: 'Edvard Storms gate',
#   53: 'Elisenberg',
#   54: 'Enerhaugen',
#   55: 'Ensjø T-bane',
#   56: 'Ensjøveien',
#   57: 'Fagerheimgata',
#   58: 'Filipstadveien',
#   59: 'Finnmarksgata',
#   60: 'Forskningsveien',
#   61: 'Fram-gården',
#   62: 'Fred Olsens gate',
#   63: 'Fredensborg',
#   64: 'Friggfeltet',
#   65: 'Frogner plass',
#   66: 'Frogner Stadion',
#   67: 'Frogner Tennisklubb',
#   68: 'Frognerbadet',
#   69: 'Frognerstranda',
#   70: 'Frognerveien',
#   71: 'Frøen T-bane',
#   72: 'Furulund',
#   73: 'Fyrstikktorget',
#   74: 'Fysikkbygningen',
#   75: 'Galgeberg',
#   76: 'Gaustad T-bane',
#   77: 'Georg Morgenstiernes hus',
#   78: 'Gimle Kino',
#   79: 'Goethe Institut',
#   80: 'Grenseveien',
#   81: 'Griffenfeldts gate',
# ...
#   101: 'Huk',
#   102: 'Hydroparken',
#   103: 'Idioten',
#   104: 'Ila',
#   105: 'Jakob kirke',
#   106: 'Jarlsborgveien',
#   107: 'Jenny Braatens Plass',
#   108: 'Jens Bjelkes gate',
#   109: 'Jernbanetorget',
#   110: 'Jess Carlsens gate',
#   111: 'John Colletts plass',
#   112: 'Jordalgata',
#   113: 'Kampen park Øst',
#   114: 'Karenlyst allé',
#   115: 'Kirkegata 15',
#   116: 'Kirkeristen',
#   117: 'Kirkeveien',
#   118: 'Kjeld Stubs gate',
#   119: 'Kontraskjæret',
#   120: "Krebs' gate",
#   121: 'Kværnerbyen',
#   122: 'Københavngata busstopp',
#   123: 'Lakkegata',
#   124: 'Landstads gate',
#   125: 'Langkaia',
#   126: 'Lille Grensen',
#   127: 'Lilleborgbanen',
#   128: 'Linaaes gate',
#   129: 'Lindern',
#   130: 'Lodalen busstopp',
#   131: 'Lørenveien',
#   132: 'Mailundveien',
#   133: 'Majorstua skole',
#   134: 'Majorstuen',
#   135: 'Majorstuen T-bane',
#   136: 'Majorstuveien',
#   137: 'Mandalls gate',
#   138: 'Marcus Thranes gate',
#   139: 'Marienlyst',
#   140: 'Marienlystparken',
#   141: 'Meltzers gate',
#   142: 'Monolittveien',
#   143: 'Munkegata trikkestopp',
#   144: 'Myraløkka Øst',
#   145: 'Mølleparken',
#   146: 'Møllergata',
#   147: 'Nedre Slottsgate',
#   148: 'Nordre gate',
#   149: 'Norsk Folkemuseum',
#   150: 'Nydalen',
#   151: 'Nylandsveien',
#   152: 'Olaf Ryes plass',
#   153: 'Oscars gate',
#   154: 'Oslo Handelsgymnasium',
#   155: 'Oslo Hospital',
#   156: 'Oslo Plaza',
#   157: 'Over Rådhusgata',
#   158: 'Paléhaven',
#   159: 'Parkveien',
#   160: 'Pilestredet',
#   161: 'Pilestredet 63',
#   162: 'Pilestredet Studenthus',
#   163: 'Professor Aschehougs plass',
#   164: 'Riddervoldplass',
#   165: 'Ringnes Park',
#   166: 'Rolf Wickstrøms vei',
#   167: 'Ruseløkkgården',
#   168: 'Rådhusbrygge 4',
#   169: 'Rådhusgata',
#   170: 'Sagene bussholdeplass',
#   171: 'Salt',
#   172: 'Schives gate',
#   173: 'Schous plass',
#   174: 'Schous plass trikkestopp',
#   175: 'Sentrum Scene',
#   176: 'Sinsen T-bane',
#   177: 'Sinsenveien',
#   178: 'Sirkustomta',
#   179: 'Sjølyst',
#   180: 'Sjøsiden ved fontenen',
#   181: 'Sjøsiden ved trappen',
#   182: 'Skarpsnoparken',
#   183: 'Skillebekk',
#   184: 'Skippergata',
#   185: 'Skovveien',
#   186: 'Skråninga',
#   187: 'Skøyen',
#   188: 'Skøyen Stasjon',
#   189: 'Slemdalsveien',
#   190: 'Slottsparken Øst',
#   191: 'Sofienberggata',
#   192: 'Sofienbergparken nord',
#   193: 'Sofienbergparken nordvest',
#   194: 'Sofienbergparken sør',
#   195: 'Sognsveien',
#   196: 'Sommerfrydhagen',
#   197: 'Sotahjørnet',
#   198: 'Spikersuppa Vest',
#   199: 'Spikersuppa Øst',
#   200: 'St. Hanshaugen',
#   201: 'St. Hanshaugen park nord',
#   202: 'St. Hanshaugen park sør',
#   203: 'St. Hanshaugen park vest',
#   204: 'St. Olavs gate',
#   205: 'Stavangergata',
#   206: 'Stensgata',
#   207: 'Stensparken',
#   208: 'Stockfleths gate',
#   209: 'Storgata',
#   210: 'Storo Storsenter',
#   211: 'Studenterlunden',
#   212: 'Studentparlamentet',
#   213: 'Suhms gate',
#   214: 'Sukkerbiten',
#   215: 'Søndre gate',
#   216: 'Sørvest for Slottsparken',
#   217: 'Tannlegehøyskolen',
#   218: 'Thereses gate',
#   219: 'Thomas Heftyes plass',
#   220: 'Thune',
#   221: 'Tjuvholmen',
#   222: 'Tordenskiolds gate',
#   223: 'Torggata',
#   224: 'Torshovdalen øst',
#   225: 'Torshovparken vest',
#   226: 'Trelastgata',
#   227: 'Trondheimsveien',
#   228: 'Tøyen skole',
#   229: 'Tøyenbekken',
#   230: 'Tøyenparken',
#   231: 'Tåsen Senter',
#   232: 'Tåsenløkka',
#   233: 'Uelands gate',
#   234: 'Ullevål sykehus',
#   235: 'Ullevålsalléen',
#   236: 'Ullevålsveien',
#   237: 'Uranienborgparken',
#   238: 'Uranienborgveien',
#   239: 'Valkyrieplassen',
#   240: 'Vaterlandsparken',
#   241: 'Vestkanttorvet',
#   242: 'Vippetangen vest',
#   243: 'Vippetangen øst',
#   244: 'Volvat',
#   245: 'Vulkan',
#   246: 'Vålerenga',
#   247: 'Vår Frelsers gravlund sør',
#   248: 'Økernveien',
#   249: 'Totalsum',
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  'c_sep': {0: 'Antall av ended_at',
#   1: 2546,
#   2: 745,
#   3: 2362,
#   4: 2747,
#   5: 3657,
#   6: 1584,
#   7: 1221,
#   8: 863,
#   9: 1156,
#   10: 1042,
#   11: 739,
#   12: 373,
#   13: 338,
#   14: 300,
#   15: 3256,
#   16: 891,
#   17: 56,
#   18: 874,
#   19: 2464,
#   20: 1100,
#   21: 2621,
#   22: 2041,
#   23: 1923,
#   24: 1085,
#   25: 445,
#   26: 797,
#   27: 443,
#   28: 2896,
#   29: 275,
#   30: 2292,
#   31: 170,
#   32: 2188,
#   33: 945,
#   34: 903,
#   35: 943,
#   36: 1075,
#   37: 97,
#   38: 478,
#   39: 120,
#   40: 1377,
#   41: 908,
#   42: 725,
#   43: 450,
#   44: 827,
#   45: 487,
#   46: 262,
#   47: 1616,
#   48: 537,
#   49: 681,
#   50: 1304,
#   51: 1006,
#   52: 1542,
#   53: 1310,
#   54: 624,
#   55: 495,
#   56: 285,
#   57: 1704,
#   58: 2188,
#   59: 592,
#   60: 222,
#   61: 1343,
#   62: 1747,
#   63: 1786,
#   64: 359,
#   65: 1347,
#   66: 769,
#   67: 373,
#   68: 458,
#   69: 1339,
#   70: 741,
#   71: 301,
#   72: 104,
#   73: 255,
#   74: 434,
#   75: 801,
#   76: 48,
#   77: 575,
#   78: 1274,
#   79: 231,
#   80: 136,
#   81: 543,
#   82: 1190,
#   83: 1380,
#   84: 981,
#   85: 900,
#   86: 1785,
#   87: 711,
#   88: 159,
#   89: 477,
#   90: 134,
#   91: 1035,
#   92: 954,
#   93: 3727,
#   94: 1979,
#   95: 1212,
#   96: 1813,
#   97: 686,
#   98: 601,
#   99: 1442,
#   100: 1580,
#   101: 521,
#   102: 970,
#   103: 514,
#   104: 469,
#   105: 2727,
#   106: 111,
#   107: 702,
#   108: 1965,
#   109: 2825,
#   110: 2256,
#   111: 276,
#   112: 698,
#   113: 179,
#   114: 2110,
#   115: 891,
#   116: 2464,
#   117: 330,
#   118: 560,
#   119: 1081,
#   120: 670,
#   121: 1569,
#   122: 492,
#   123: 1955,
#   124: 969,
#   125: 472,
#   126: 1309,
#   127: 702,
#   128: 1103,
#   129: 249,
#   130: 347,
#   131: 387,
#   132: 156,
#   133: 904,
#   134: 2055,
#   135: 288,
#   136: 748,
#   137: 997,
#   138: 1361,
#   139: 483,
#   140: 746,
#   141: 475,
#   142: 193,
#   143: 1728,
#   144: 1044,
#   145: 1609,
#   146: 2188,
#   147: 802,
#   148: 1253,
#   149: 650,
#   150: 143,
#   151: 1757,
#   152: 3738,
#   153: 1580,
#   154: 1127,
#   155: 1026,
#   156: 1194,
#   157: 1143,
#   158: 2761,
#   159: 1516,
#   160: 691,
#   161: 1149,
#   162: 878,
#   163: 538,
#   164: 766,
#   165: 3729,
#   166: 68,
#   167: 1205,
#   168: 4966,
#   169: 1580,
#   170: 835,
#   171: 727,
#   172: 764,
#   173: 3200,
#   174: 1558,
#   175: 4994,
#   176: 272,
#   177: 224,
#   178: 682,
#   179: 528,
#   180: 1904,
#   181: 4185,
#   182: 378,
#   183: 1341,
#   184: 986,
#   185: 1298,
#   186: 1472,
#   187: 1544,
#   188: 655,
#   189: 1247,
#   190: 1386,
#   191: 1087,
#   192: 2078,
#   193: 1977,
#   194: 1268,
#   195: 493,
#   196: 1314,
#   197: 471,
#   198: 5499,
#   199: 2020,
#   200: 1221,
#   201: 446,
#   202: 669,
#   203: 743,
#   204: 2105,
#   205: 748,
#   206: 886,
#   207: 1186,
#   208: 478,
#   209: 1378,
#   210: 650,
#   211: 1882,
#   212: 1170,
#   213: 793,
#   214: 2469,
#   215: 2198,
#   216: 151,
#   217: 498,
#   218: 427,
#   219: 1318,
#   220: 1049,
#   221: 3240,
#   222: 714,
#   223: 4870,
#   224: 304,
#   225: 254,
#   226: 1339,
#   227: 808,
#   228: 2734,
#   229: 2401,
#   230: 708,
#   231: 158,
#   232: 399,
#   233: 818,
#   234: 901,
#   235: 200,
#   236: 526,
#   237: 572,
#   238: 1575,
#   239: 412,
#   240: 3408,
#   241: 814,
#   242: 1567,
#   243: 609,
#   244: 253,
#   245: 2358,
#   246: 568,
#   247: 2935,
#   248: 278,
#   249: 292586,
#   250: nan,
#   251: nan,
#   252: nan,
#   253: nan},
#  '10': {0: 'Radetiketter',
#   1: '7 Juni Plassen',
#   2: 'Adamstuen',
#   3: 'AHO',
#   4: 'Akersgata',
#   5: 'Alexander Kiellands Plass',
#   6: 'Anker Hostel',
#   7: 'Annette Thommessens Plass',
#   8: 'Arendalsgata',
#   9: 'Arkaden Nord',
#   10: 'Arkaden Sør',
#   11: 'Arkitekt Rivertz Plass',
#   12: 'Badebakken',
#   13: 'Bak Niels Treschows hus nord',
#   14: 'Bak Niels Treschows hus sør',
#   15: 'Bankplassen',
#   16: 'Bentsebrugata',
#   17: 'BI Nydalen',
#   18: 'Birkelunden',
#   19: "Biskop Gunnerus' gate",
#   20: 'Bislett Stadion',
#   21: 'Bislettgata',
#   22: 'Bjerregaards gate',
#   23: 'Bjerregaardsgate Øst',
#   24: 'Bjølsen mølle',
#   25: 'Bjølsen Studentby',
#   26: 'Bjølsendumpa',
#   27: 'Bjørvika',
#   28: 'Blindern studentparkering',
#   29: 'Bogstadveien',
#   30: 'Borgenveien',
#   31: 'Botanisk Hage sør',
#   32: 'Botanisk hage sør-vest',
#   33: 'Botanisk Hage vest',
#   34: 'Briskeby',
#   35: 'Brugata',
#   36: 'Brynseng T-bane',
#   37: 'Bygdøy allé',
#   38: 'Bøkkerveien',
#   39: 'Carl Berners plass sør',
#   40: 'Chr. Michelsens Gate',
#   41: 'Colbjørnsens gate',
#   42: 'Colletts gate',
#   43: 'Colosseum Kino',
#   44: 'Det Teologiske fakultet',
#   45: 'Diakonhjemmet',
#   46: 'Dokkveien',
#   47: 'Drammensveien',
#   48: 'Dronningens gate',
#   49: 'Dyvekes bru',
#   50: 'Dælenenggata',
#   51: 'Edvard Storms gate',
#   52: 'Elisenberg',
#   53: 'Enerhaugen',
#   54: 'Ensjø T-bane',
#   55: 'Ensjøveien',
#   56: 'Fagerheimgata',
#   57: 'Filipstadveien',
#   58: 'Finnmarksgata',
#   59: 'Forskningsveien',
#   60: 'Fram-gården',
#   61: 'Fred Olsens gate',
#   62: 'Fredensborg',
#   63: 'Friggfeltet',
#   64: 'Frogner plass',
#   65: 'Frogner Stadion',
#   66: 'Frogner Tennisklubb',
#   67: 'Frognerbadet',
#   68: 'Frognerstranda',
#   69: 'Frognerveien',
#   70: 'Frøen T-bane',
#   71: 'Furulund',
#   72: 'Fyrstikktorget',
#   73: 'Fysikkbygningen',
#   74: 'Galgeberg',
#   75: 'Gaustad T-bane',
#   76: 'Georg Morgenstiernes hus',
#   77: 'Gimle Kino',
#   78: 'Goethe Institut',
#   79: 'Grenseveien',
#   80: 'Griffenfeldts gate',
#   81: 'Grünerhagen Nord',
#   82: 'Grønlands torg',
#   83: 'Hallénparken',
#   84: 'Hallings gate',
#   85: 'Hammersborg Torg',
#   86: 'Hans Nielsen Hauges plass',
#   87: 'Hasle',
#   88: 'Hasle Torg',
#   89: 'HasleLinje',
#   90: 'Hausmanns bru',
#   91: 'Hausmanns gate',
#   92: 'Helga Helgesens plass',
#   93: 'Henrik Ibsens gate',
#   94: 'Henrik Wergelands allé',
#   95: 'HiOA',
#   96: 'Hoff terrasse holdeplass',
#   97: 'Hoffsveien',
#   98: 'Holbergs Plass',
#   99: 'Huitfeldts gate',
#   100: 'Huk',
#   101: 'Hydroparken',
#   102: 'Idioten',
#   103: 'Ila',
#   104: 'Jakob kirke',
#   105: 'Jarlsborgveien',
#   106: 'Jenny Braatens Plass',
#   107: 'Jens Bjelkes gate',
#   108: 'Jernbanetorget',
#   109: 'Jess Carlsens gate',
#   110: 'John Colletts plass',
#   111: 'Jordalgata',
#   112: 'Kampen park Øst',
#   113: 'Karenlyst allé',
#   114: 'Kirkegata 15',
#   115: 'Kirkeristen',
#   116: 'Kirkeveien',
#   117: 'Kjeld Stubs gate',
#   118: 'Kontraskjæret',
#   119: "Krebs' gate",
#   120: 'Kværnerbyen',
#   121: 'Københavngata busstopp',
#   122: 'Lakkegata',
#   123: 'Landstads gate',
#   124: 'Langkaia',
#   125: 'Lille Grensen',
#   126: 'Lilleborgbanen',
#   127: 'Linaaes gate',
#   128: 'Lindern',
#   129: 'Lodalen busstopp',
#   130: 'Lørenveien',
#   131: 'Mailundveien',
#   132: 'Majorstua skole',
#   133: 'Majorstuen',
#   134: 'Majorstuen T-bane',
#   135: 'Majorstuveien',
#   136: 'Mandalls gate',
#   137: 'Marcus Thranes gate',
#   138: 'Marienlyst',
#   139: 'Marienlystparken',
#   140: 'Meltzers gate',
#   141: 'Monolittveien',
#   142: 'Munkedamsveien',
#   143: 'Munkegata trikkestopp',
#   144: 'Myraløkka Øst',
#   145: 'Mølleparken',
#   146: 'Møllergata',
#   147: 'Nedre Slottsgate',
#   148: 'Nordre gate',
#   149: 'Norsk Folkemuseum',
#   150: 'Nydalen',
#   151: 'Nylandsveien',
#   152: 'Olaf Ryes plass',
#   153: 'Oscars gate',
#   154: 'Oslo Handelsgymnasium',
#   155: 'Oslo Hospital',
#   156: 'Oslo Plaza',
#   157: 'Over Rådhusgata',
#   158: 'Paléhaven',
#   159: 'Parkveien',
#   160: 'Pilestredet',
#   161: 'Pilestredet 63',
#   162: 'Pilestredet Studenthus',
#   163: 'Professor Aschehougs plass',
#   164: 'Riddervoldplass',
#   165: 'Ringnes Park',
#   166: 'Rolf Wickstrøms vei',
#   167: 'Ruseløkkgården',
#   168: 'Rådhusbrygge 4',
#   169: 'Rådhusgata',
#   170: 'Sagene bussholdeplass',
#   171: 'Salt',
#   172: 'Schives gate',
#   173: 'Schous plass',
#   174: 'Schous plass trikkestopp',
#   175: 'Sentrum Scene',
#   176: 'Sinsen T-bane',
#   177: 'Sinsenveien',
#   178: 'Sirkustomta',
#   179: 'Sjølyst',
#   180: 'Sjøsiden ved fontenen',
#   181: 'Sjøsiden ved trappen',
#   182: 'Skarpsnoparken',
#   183: 'Skillebekk',
#   184: 'Skippergata',
#   185: 'Skovveien',
#   186: 'Skråninga',
#   187: 'Skøyen',
#   188: 'Skøyen Stasjon',
#   189: 'Slemdalsveien',
#   190: 'Slottsparken Øst',
#   191: 'Sofienberggata',
#   192: 'Sofienbergparken nord',
#   193: 'Sofienbergparken nordvest',
#   194: 'Sofienbergparken sør',
#   195: 'Sognsveien',
#   196: 'Sommerfrydhagen',
#   197: 'Sotahjørnet',
#   198: 'Spikersuppa Vest',
#   199: 'Spikersuppa Øst',
#   200: 'St. Hanshaugen',
#   201: 'St. Hanshaugen park nord',
#   202: 'St. Hanshaugen park sør',
#   203: 'St. Hanshaugen park vest',
#   204: 'St. Olavs gate',
#   205: 'Stavangergata',
#   206: 'Stensgata',
#   207: 'Stensparken',
#   208: 'Stockfleths gate',
#   209: 'Storgata',
#   210: 'Storo Storsenter',
#   211: 'Stortingstunellen',
#   212: 'Studenterlunden',
#   213: 'Studentparlamentet',
#   214: 'Suhms gate',
#   215: 'Sukkerbiten',
#   216: 'Søndre gate',
#   217: 'Sørvest for Slottsparken',
#   218: 'Tannlegehøyskolen',
#   219: 'Thereses gate',
#   220: 'Thomas Heftyes plass',
#   221: 'Thune',
#   222: 'Tjuvholmen',
#   223: 'Tordenskiolds gate',
#   224: 'Torggata',
#   225: 'Torshovdalen øst',
#   226: 'Torshovparken vest',
#   227: 'Trelastgata',
#   228: 'Trondheimsveien',
#   229: 'Tøyen skole',
#   230: 'Tøyenbekken',
#   231: 'Tøyenparken',
#   232: 'Tåsen Senter',
#   233: 'Tåsenløkka',
#   234: 'Uelands gate',
#   235: 'Ullevål sykehus',
#   236: 'Ullevålsalléen',
#   237: 'Ullevålsveien',
#   238: 'Uranienborgparken',
#   239: 'Uranienborgveien',
#   240: 'Valkyrieplassen',
#   241: 'Vaterlandsparken',
#   242: 'Vestkanttorvet',
#   243: 'Vippetangen vest',
#   244: 'Vippetangen øst',
#   245: 'Volvat',
#   246: 'Vulkan',
#   247: 'Vålerenga',
#   248: 'Vår Frelsers gravlund sør',
#   249: 'Økernveien',
#   250: 'Totalsum',
#   251: nan,
#   252: nan,
#   253: nan},
#  'c_oct': {0: 'Antall av ended_at',
#   1: 1718,
#   2: 473,
#   3: 1662,
#   4: 2056,
#   5: 2401,
#   6: 1005,
#   7: 826,
#   8: 561,
#   9: 854,
#   10: 505,
#   11: 470,
#   12: 299,
#   13: 250,
#   14: 260,
#   15: 2246,
#   16: 628,
#   17: 566,
#   18: 1343,
#   19: 823,
#   20: 1687,
#   21: 1392,
#   22: 1228,
#   23: 755,
#   24: 272,
#   25: 539,
#   26: 301,
#   27: 2016,
#   28: 192,
#   29: 1504,
#   30: 103,
#   31: 1442,
#   32: 597,
#   33: 503,
#   34: 633,
#   35: 959,
#   36: 75,
#   37: 328,
#   38: 121,
#   39: 752,
#   40: 468,
#   41: 519,
#   42: 247,
#   43: 572,
#   44: 349,
#   45: 220,
#   46: 1061,
#   47: 371,
#   48: 488,
#   49: 737,
#   50: 653,
#   51: 998,
#   52: 825,
#   53: 342,
#   54: 367,
#   55: 178,
#   56: 1094,
#   57: 1443,
#   58: 388,
#   59: 170,
#   60: 905,
#   61: 1228,
#   62: 1297,
#   63: 259,
#   64: 774,
#   65: 469,
#   66: 136,
#   67: 356,
#   68: 907,
#   69: 461,
#   70: 233,
#   71: 42,
#   72: 158,
#   73: 275,
#   74: 498,
#   75: 54,
#   76: 475,
#   77: 768,
#   78: 269,
#   79: 84,
#   80: 369,
#   81: 796,
#   82: 1152,
#   83: 649,
#   84: 596,
#   85: 1465,
#   86: 477,
#   87: 94,
#   88: 291,
#   89: 89,
#   90: 578,
#   91: 729,
#   92: 2525,
#   93: 1202,
#   94: 320,
#   95: 1200,
#   96: 494,
#   97: 431,
#   98: 874,
#   99: 1088,
#   100: 168,
#   101: 655,
#   102: 354,
#   103: 319,
#   104: 1483,
#   105: 49,
#   106: 419,
#   107: 1411,
#   108: 1976,
#   109: 1514,
#   110: 192,
#   111: 412,
#   112: 149,
#   113: 1352,
#   114: 710,
#   115: 1906,
#   116: 214,
#   117: 397,
#   118: 771,
#   119: 433,
#   120: 1062,
#   121: 293,
#   122: 1433,
#   123: 646,
#   124: 435,
#   125: 921,
#   126: 399,
#   127: 1025,
#   128: 159,
#   129: 204,
#   130: 253,
#   131: 84,
#   132: 763,
#   133: 1230,
#   134: 54,
#   135: 513,
#   136: 606,
#   137: 975,
#   138: 378,
#   139: 438,
#   140: 328,
#   141: 147,
#   142: 120,
#   143: 1116,
#   144: 727,
#   145: 934,
#   146: 1135,
#   147: 655,
#   148: 741,
#   149: 252,
#   150: 122,
#   151: 1304,
#   152: 2218,
#   153: 981,
#   154: 852,
#   155: 658,
#   156: 814,
#   157: 884,
#   158: 1497,
#   159: 1036,
#   160: 513,
#   161: 708,
#   162: 487,
#   163: 566,
#   164: 433,
#   165: 2652,
#   166: 36,
#   167: 802,
#   168: 3171,
#   169: 813,
#   170: 535,
#   171: 453,
#   172: 526,
#   173: 2284,
#   174: 1066,
#   175: 3506,
#   176: 186,
#   177: 147,
#   178: 406,
#   179: 352,
#   180: 739,
#   181: 2765,
#   182: 213,
#   183: 1014,
#   184: 697,
#   185: 738,
#   186: 1456,
#   187: 1074,
#   188: 455,
#   189: 884,
#   190: 829,
#   191: 734,
#   192: 1350,
#   193: 1251,
#   194: 802,
#   195: 318,
#   196: 808,
#   197: 345,
#   198: 3392,
#   199: 1428,
#   200: 794,
#   201: 279,
#   202: 298,
#   203: 402,
#   204: 1249,
#   205: 443,
#   206: 597,
#   207: 832,
#   208: 329,
#   209: 63,
#   210: 477,
#   211: 233,
#   212: 1087,
#   213: 834,
#   214: 537,
#   215: 1733,
#   216: 1552,
#   217: 234,
#   218: 329,
#   219: 314,
#   220: 823,
#   221: 715,
#   222: 2199,
#   223: 480,
#   224: 4017,
#   225: 265,
#   226: 126,
#   227: 1130,
#   228: 524,
#   229: 1683,
#   230: 1456,
#   231: 454,
#   232: 118,
#   233: 268,
#   234: 510,
#   235: 635,
#   236: 158,
#   237: 417,
#   238: 339,
#   239: 1148,
#   240: 542,
#   241: 1986,
#   242: 493,
#   243: 1092,
#   244: 370,
#   245: 160,
#   246: 1541,
#   247: 326,
#   248: 1980,
#   249: 185,
#   250: 193868,
#   251: nan,
#   252: nan,
#   253: nan}}

# %%
one = df1[['04','05','06','07','08','09','10']].melt().rename({'variable':'','value':'COL1.'},axis=1)
one
# Out:
#                    COL1.
# 0     04    Radetiketter
# 1     04  7 Juni Plassen
# 2     04       Adamstuen
# 3     04             AHO
# 4     04       Akersgata
# ...   ..             ...
# 1773  10      Økernveien
# 1774  10        Totalsum
# 1775  10             NaN
# 1776  10             NaN
# 1777  10             NaN
#
# [1778 rows x 2 columns]

# %%
two = df1[['c_april','c_may','c_jun','c_july','c_aug','c_sep','c_oct']].melt().drop('variable',axis=1).rename({'value':'count'},axis=1)
two
# Out:
#                    count
# 0     Antall av ended_at
# 1                   1293
# 2                    567
# 3                   1799
# 4                   2418
# ...                  ...
# 1773                 185
# 1774              193868
# 1775                 NaN
# 1776                 NaN
# 1777                 NaN
#
# [1778 rows x 1 columns]

# %%
out = pd.concat([one,two],axis=1).reindex(['COL1.','count',''], axis=1)
out = out.replace(np.nan, '', regex=True)
out = out[1:]
out = out.rename(columns={'': 'month'})
out
# Out:
#                           COL1.   count month
# 1                7 Juni Plassen    1293    04
# 2                     Adamstuen     567    04
# 3                           AHO    1799    04
# 4                     Akersgata    2418    04
# 5     Alexander Kiellands Plass    3238    04
# ...                         ...     ...   ...
# 1773                 Økernveien     185    10
# 1774                   Totalsum  193868    10
# 1775                                       10
# 1776                                       10
# 1777                                       10
#
# [1777 rows x 3 columns]

# %%
out['month'] = out['month'].astype('int64')
out
# Out:
#                           COL1.   count  month
# 1                7 Juni Plassen    1293      4
# 2                     Adamstuen     567      4
# 3                           AHO    1799      4
# 4                     Akersgata    2418      4
# 5     Alexander Kiellands Plass    3238      4
# ...                         ...     ...    ...
# 1773                 Økernveien     185     10
# 1774                   Totalsum  193868     10
# 1775                                        10
# 1776                                        10
# 1777                                        10
#
# [1777 rows x 3 columns]

# %%
out.columns.tolist()
# Out:
# ['COL1.', 'count', 'month']

# %%
dataTypeSeries = df3.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# Unnamed: 0                     int64
# started_at                    object
# ended_at                      object
# duration                       int64
# start_station_id               int64
# start_station_name            object
# start_station_description     object
# start_station_latitude       float64
# start_station_longitude      float64
# end_station_id                 int64
# end_station_name              object
# end_station_description       object
# end_station_latitude         float64
# end_station_longitude        float64
# dtype: object

# %%
#The shape of data set.
print('The shape of our features is:', df3.shape)
df3=df3.replace(np.nan,0)
# Out:
# The shape of our features is: (235713, 14)

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0                   0
# started_at                   0
# ended_at                     0
# duration                     0
# start_station_id             0
# start_station_name           0
# start_station_description    0
# start_station_latitude       0
# start_station_longitude      0
# end_station_id               0
# end_station_name             0
# end_station_description      0
# end_station_latitude         0
# end_station_longitude        0
# dtype: int64

# %%
df5['start_station_id'].nunique()
# Out:
# 247

# %%
res1 = df3.append(df4).reset_index()
res2 = res1.append(df5).reset_index()
res2=res2.drop(['level_0','index','Unnamed: 0'], axis=1)

res3 = res2.append(df6).reset_index()

res4 = res3.append(df7).reset_index()
res4=res4.drop(['level_0','index'], axis=1)


res5 = res4.append(df8).reset_index()

result = res5.append(df9).reset_index()
result=result.drop(['index','Unnamed: 0'], axis=1)

# %%
result['month'] = pd.DatetimeIndex(result['started_at']).month
result[:3]
# Out:
#    level_0                        started_at  \
# 0        0  2019-04-02 22:18:47.926000+00:00
# 1        1  2019-04-02 22:25:54.203000+00:00
# 2        2  2019-04-02 22:26:39.308000+00:00
#
#                            ended_at  duration  start_station_id  \
# 0  2019-04-02 22:24:25.427000+00:00       337               401
# 1  2019-04-02 22:27:36.114000+00:00       101               556
# 2  2019-04-02 22:31:59.445000+00:00       320               561
#
#   start_station_name     start_station_description  start_station_latitude  \
# 0       Schous plass  nærmest Thorvald Meyers gate               59.920259
# 1        Pilestredet              ved Sporveisgata               59.926224
# 2         Kirkeveien        nord for Gørbitz' gate               59.933558
#
#    start_station_longitude  end_station_id end_station_name  \
# 0                10.760629             381   Grønlands torg
# 1                10.729625             556      Pilestredet
# 2                10.726426             471       Marienlyst
#
#   end_station_description  end_station_latitude  end_station_longitude  month
# 0         ved Tøyenbekken             59.912520              10.762240      4
# 1        ved Sporveisgata             59.926224              10.729625      4
# 2            i Suhms gate             59.932454              10.721769      4

# %%
print(result['month'].unique())
# Out:
# [ 4  5  6  7  8  9 10]

# %%
result['start_station_name'].nunique()
# Out:
# 259

# %%
result['combined'] = result['start_station_id'].astype(str)+result['end_station_id'].astype(str)
result[:3]
# Out:
#    level_0                        started_at  \
# 0        0  2019-04-02 22:18:47.926000+00:00
# 1        1  2019-04-02 22:25:54.203000+00:00
# 2        2  2019-04-02 22:26:39.308000+00:00
#
#                            ended_at  duration  start_station_id  \
# 0  2019-04-02 22:24:25.427000+00:00       337               401
# 1  2019-04-02 22:27:36.114000+00:00       101               556
# 2  2019-04-02 22:31:59.445000+00:00       320               561
#
#   start_station_name     start_station_description  start_station_latitude  \
# 0       Schous plass  nærmest Thorvald Meyers gate               59.920259
# 1        Pilestredet              ved Sporveisgata               59.926224
# 2         Kirkeveien        nord for Gørbitz' gate               59.933558
#
#    start_station_longitude  end_station_id end_station_name  \
# 0                10.760629             381   Grønlands torg
# 1                10.729625             556      Pilestredet
# 2                10.726426             471       Marienlyst
#
#   end_station_description  end_station_latitude  end_station_longitude  month  \
# 0         ved Tøyenbekken             59.912520              10.762240      4
# 1        ved Sporveisgata             59.926224              10.729625      4
# 2            i Suhms gate             59.932454              10.721769      4
#
#   combined
# 0   401381
# 1   556556
# 2   561471

# %%
result['combined'].nunique()
#we just have 54777 uniqe FROM to TO station . #lets sum the duration of each similar row.
#and drop the duplicate row.
# Out:
# 57544

# %%
#Group by based on the combined id and we some the duration 
result["sum"] = result.groupby('combined')['duration'].transform('sum')
df1 = result.drop_duplicates('combined')
df1[:10]
# Out:
#    level_0                        started_at  \
# 0        0  2019-04-02 22:18:47.926000+00:00
# 1        1  2019-04-02 22:25:54.203000+00:00
# 2        2  2019-04-02 22:26:39.308000+00:00
# 3        3  2019-04-03 03:09:58.992000+00:00
# 4        4  2019-04-03 03:10:02.415000+00:00
# 5        5  2019-04-03 03:16:21.557000+00:00
# 6        6  2019-04-03 03:39:11.948000+00:00
# 7        7  2019-04-03 03:43:38.513000+00:00
# 8        8  2019-04-03 03:46:23.126000+00:00
# 9        9  2019-04-03 03:50:36.147000+00:00
#
#                            ended_at  duration  start_station_id  \
# 0  2019-04-02 22:24:25.427000+00:00       337               401
# 1  2019-04-02 22:27:36.114000+00:00       101               556
# 2  2019-04-02 22:31:59.445000+00:00       320               561
# 3  2019-04-03 03:12:00.589000+00:00       121               393
# 4  2019-04-03 03:14:44.537000+00:00       282               597
# 5  2019-04-03 03:27:20.124000+00:00       658               471
# 6  2019-04-03 03:42:46.377000+00:00       214               598
# 7  2019-04-03 03:50:02.914000+00:00       384               462
# 8  2019-04-03 04:00:40.509000+00:00       857               461
# 9  2019-04-03 03:56:15.344000+00:00       339               463
#
#           start_station_name        start_station_description  \
# 0               Schous plass     nærmest Thorvald Meyers gate
# 1                Pilestredet                 ved Sporveisgata
# 2                 Kirkeveien           nord for Gørbitz' gate
# 3  Hans Nielsen Hauges plass  Mellom Åsengata og Nordkappgata
# 4                Fredensborg                ved rundkjøringen
# 5                 Marienlyst                     i Suhms gate
# 6      Sofienbergparken nord             langs Helgesens gate
# 7                Stensparken                 ved Sporveisgata
# 8                  Vålerenga             langs Ingeborgs gate
# 9   Schous plass trikkestopp                  ved biblioteket
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               59.920259                10.760629             381
# 1               59.926224                10.729625             556
# 2               59.933558                10.726426             471
# 3               59.939244                10.774319             393
# 4               59.920995                10.750358             557
# 5               59.932454                10.721769             412
# 6               59.923229                10.766171             401
# 7               59.927140                10.730981             613
# 8               59.908576                10.786856             385
# 9               59.920728                10.759486             448
#
#             end_station_name          end_station_description  \
# 0             Grønlands torg                  ved Tøyenbekken
# 1                Pilestredet                 ved Sporveisgata
# 2                 Marienlyst                     i Suhms gate
# 3  Hans Nielsen Hauges plass  Mellom Åsengata og Nordkappgata
# 4                  Akersgata                      ved Grensen
# 5                Jakob kirke                   langs Torggata
# 6               Schous plass     nærmest Thorvald Meyers gate
# 7               Schives gate             ved Arno Bergs plass
# 8                Søndre gate                    ved Ankerbrua
# 9                 Oslo Plaza                ved rundkjøringen
#
#    end_station_latitude  end_station_longitude  month combined     sum
# 0             59.912520              10.762240      4   401381   32290
# 1             59.926224              10.729625      4   556556   35628
# 2             59.932454              10.721769      4   561471   12867
# 3             59.939244              10.774319      4   393393  195132
# 4             59.914197              10.742883      4   597557  190271
# 5             59.917866              10.754898      4   471412   12700
# 6             59.920259              10.760629      4   598401   44248
# 7             59.920804              10.714054      4   462613   19203
# 8             59.918632              10.757867      4   461385   21880
# 9             59.912185              10.754506      4   463448   31665

# %%
check = result[result['combined'].str.contains('561471')]
check
# Out:
#          level_0                        started_at  \
# 2              2  2019-04-02 22:26:39.308000+00:00
# 24335      24335  2019-04-06 14:34:38.038000+00:00
# 53253      53253  2019-04-10 13:43:58.701000+00:00
# 147901    147901  2019-04-22 19:55:19.710000+00:00
# 308640    308640  2019-05-07 22:48:59.242000+00:00
# 433282    433282  2019-05-20 20:16:03.985000+00:00
# 549657    549657  2019-05-30 21:25:26.538000+00:00
# 635364    635364  2019-06-09 14:15:50.617000+00:00
# 687483    687483  2019-06-14 11:56:09.731000+00:00
# 861618    861618  2019-06-28 17:39:58.105000+00:00
# 899565    899565  2019-07-02 21:34:40.358000+00:00
# 1070540  1070540  2019-07-18 21:40:58.960000+00:00
# 1086532  1086532  2019-07-21 13:38:53.867000+00:00
# 1110515  1110515  2019-07-23 22:02:08.356000+00:00
# 1173421  1173421  2019-07-29 17:13:09.242000+00:00
# 1296274  1296274  2019-08-09 13:22:01.463000+00:00
# 1466939  1466939  2019-08-23 10:56:05.969000+00:00
# 1513177  1513177  2019-08-26 20:03:38.340000+00:00
# 1864356  1864356  2019-09-29 14:44:56.073000+00:00
# 1875025     8017  2019-10-01 16:14:12.596000+00:00
# 1886157    19149  2019-10-02 20:17:57.838000+00:00
# 1929980    62972  2019-10-09 13:47:44.409000+00:00
# 1952220    85212  2019-10-12 13:46:47.558000+00:00
#
#                                  ended_at  duration  start_station_id  \
# 2        2019-04-02 22:31:59.445000+00:00       320               561
# 24335    2019-04-06 14:37:01.427000+00:00       143               561
# 53253    2019-04-10 13:52:50.666000+00:00       531               561
# 147901   2019-04-22 19:56:55.466000+00:00        95               561
# 308640   2019-05-07 23:42:01.050000+00:00      3181               561
# 433282   2019-05-20 20:18:19.009000+00:00       135               561
# 549657   2019-05-30 21:38:05.733000+00:00       759               561
# 635364   2019-06-09 15:24:53.620000+00:00      4143               561
# 687483   2019-06-14 11:57:39.176000+00:00        89               561
# 861618   2019-06-28 17:41:50.797000+00:00       112               561
# 899565   2019-07-02 21:36:05.844000+00:00        85               561
# 1070540  2019-07-18 21:58:21.247000+00:00      1042               561
# 1086532  2019-07-21 13:40:29.617000+00:00        95               561
# 1110515  2019-07-23 22:04:30.181000+00:00       141               561
# 1173421  2019-07-29 17:31:19.959000+00:00      1090               561
# 1296274  2019-08-09 13:24:12.990000+00:00       131               561
# 1466939  2019-08-23 10:57:47.137000+00:00       101               561
# 1513177  2019-08-26 20:05:30.361000+00:00       112               561
# 1864356  2019-09-29 14:46:52.428000+00:00       116               561
# 1875025  2019-10-01 16:15:53.166000+00:00       100               561
# 1886157  2019-10-02 20:19:32.849000+00:00        95               561
# 1929980  2019-10-09 13:50:04.302000+00:00       139               561
# 1952220  2019-10-12 13:48:39.705000+00:00       112               561
#
#         start_station_name start_station_description  start_station_latitude  \
# 2               Kirkeveien    nord for Gørbitz' gate               59.933558
# 24335           Kirkeveien    nord for Gørbitz' gate               59.933558
# 53253           Kirkeveien    nord for Gørbitz' gate               59.933558
# 147901          Kirkeveien    nord for Gørbitz' gate               59.933558
# 308640          Kirkeveien    nord for Gørbitz' gate               59.933558
# 433282          Kirkeveien    nord for Gørbitz' gate               59.933558
# 549657          Kirkeveien    nord for Gørbitz' gate               59.933558
# 635364          Kirkeveien    nord for Gørbitz' gate               59.933558
# 687483          Kirkeveien    nord for Gørbitz' gate               59.933558
# 861618          Kirkeveien    nord for Gørbitz' gate               59.933558
# 899565          Kirkeveien    nord for Gørbitz' gate               59.933558
# 1070540         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1086532         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1110515         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1173421         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1296274         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1466939         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1513177         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1864356         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1875025         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1886157         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1929980         Kirkeveien    nord for Gørbitz' gate               59.933558
# 1952220         Kirkeveien    nord for Gørbitz' gate               59.933558
#
#          start_station_longitude  end_station_id end_station_name  \
# 2                      10.726426             471       Marienlyst
# 24335                  10.726426             471       Marienlyst
# 53253                  10.726426             471       Marienlyst
# 147901                 10.726426             471       Marienlyst
# 308640                 10.726426             471       Marienlyst
# 433282                 10.726426             471       Marienlyst
# 549657                 10.726426             471       Marienlyst
# 635364                 10.726426             471       Marienlyst
# 687483                 10.726426             471       Marienlyst
# 861618                 10.726426             471       Marienlyst
# 899565                 10.726426             471       Marienlyst
# 1070540                10.726426             471       Marienlyst
# 1086532                10.726426             471       Marienlyst
# 1110515                10.726426             471       Marienlyst
# 1173421                10.726426             471       Marienlyst
# 1296274                10.726426             471       Marienlyst
# 1466939                10.726426             471       Marienlyst
# 1513177                10.726426             471       Marienlyst
# 1864356                10.726426             471       Marienlyst
# 1875025                10.726426             471       Marienlyst
# 1886157                10.726426             471       Marienlyst
# 1929980                10.726426             471       Marienlyst
# 1952220                10.726426             471       Marienlyst
#
#         end_station_description  end_station_latitude  end_station_longitude  \
# 2                  i Suhms gate             59.932454              10.721769
# 24335              i Suhms gate             59.932454              10.721769
# 53253              i Suhms gate             59.932454              10.721769
# 147901             i Suhms gate             59.932454              10.721769
# 308640             i Suhms gate             59.932454              10.721769
# 433282             i Suhms gate             59.932454              10.721769
# 549657             i Suhms gate             59.932454              10.721769
# 635364             i Suhms gate             59.932454              10.721769
# 687483             i Suhms gate             59.932454              10.721769
# 861618             i Suhms gate             59.932454              10.721769
# 899565             i Suhms gate             59.932454              10.721769
# 1070540            i Suhms gate             59.932454              10.721769
# 1086532            i Suhms gate             59.932454              10.721769
# 1110515            i Suhms gate             59.932454              10.721769
# 1173421            i Suhms gate             59.932454              10.721769
# 1296274            i Suhms gate             59.932454              10.721769
# 1466939            i Suhms gate             59.932454              10.721769
# 1513177            i Suhms gate             59.932454              10.721769
# 1864356            i Suhms gate             59.932454              10.721769
# 1875025            i Suhms gate             59.932454              10.721769
# 1886157            i Suhms gate             59.932454              10.721769
# 1929980            i Suhms gate             59.932454              10.721769
# 1952220            i Suhms gate             59.932454              10.721769
#
#          month combined    sum
# 2            4   561471  12867
# 24335        4   561471  12867
# 53253        4   561471  12867
# 147901       4   561471  12867
# 308640       5   561471  12867
# 433282       5   561471  12867
# 549657       5   561471  12867
# 635364       6   561471  12867
# 687483       6   561471  12867
# 861618       6   561471  12867
# 899565       7   561471  12867
# 1070540      7   561471  12867
# 1086532      7   561471  12867
# 1110515      7   561471  12867
# 1173421      7   561471  12867
# 1296274      8   561471  12867
# 1466939      8   561471  12867
# 1513177      8   561471  12867
# 1864356      9   561471  12867
# 1875025     10   561471  12867
# 1886157     10   561471  12867
# 1929980     10   561471  12867
# 1952220     10   561471  12867

# %%
out= out.rename({'COL1.': 'start_station_name'}, axis=1)
out[:3]
# Out:
#   start_station_name count  month
# 1     7 Juni Plassen  1293      4
# 2          Adamstuen   567      4
# 3                AHO  1799      4

# %%
check2 = out[out['start_station_name']=='Schous plass']
check2
# Out:
#      start_station_name count  month
# 168        Schous plass  2633      4
# 421        Schous plass  3516      5
# 680        Schous plass  3601      6
# 935        Schous plass  3181      7
# 1191       Schous plass  4233      8
# 1443       Schous plass  3200      9
# 1697       Schous plass  2284     10

# %%
df1.shape
# Out:
# (57544, 17)

# %%
result2=df1.merge(out,right_on=['start_station_name','month'],left_on=['start_station_name','month'])
result2
# Out:
#        level_0                        started_at  \
# 0            0  2019-04-02 22:18:47.926000+00:00
# 1           49  2019-04-03 04:39:16.854000+00:00
# 2           94  2019-04-03 04:53:45.393000+00:00
# 3          167  2019-04-03 05:11:58.798000+00:00
# 4          320  2019-04-03 05:35:24.346000+00:00
# ...        ...                               ...
# 57505   180679  2019-10-29 07:01:34.982000+00:00
# 57506   181606  2019-10-29 08:02:30.283000+00:00
# 57507   184932  2019-10-29 16:18:04.566000+00:00
# 57508   189487  2019-10-30 10:42:21.424000+00:00
# 57509   191448  2019-10-30 15:38:49.444000+00:00
#
#                                ended_at  duration  start_station_id  \
# 0      2019-04-02 22:24:25.427000+00:00       337               401
# 1      2019-04-03 04:44:40.769000+00:00       323               401
# 2      2019-04-03 05:02:00.970000+00:00       495               423
# 3      2019-04-03 05:20:12.573000+00:00       493               423
# 4      2019-04-03 05:43:52.107000+00:00       507               423
# ...                                 ...       ...               ...
# 57505  2019-10-29 07:21:48.950000+00:00      1213               593
# 57506  2019-10-29 08:15:03.229000+00:00       752               738
# 57507  2019-10-29 16:29:17.845000+00:00       673               382
# 57508  2019-10-30 11:01:39.120000+00:00      1157               452
# 57509  2019-10-30 15:42:43.772000+00:00       234               545
#
#       start_station_name       start_station_description  \
# 0           Schous plass    nærmest Thorvald Meyers gate
# 1           Schous plass    nærmest Thorvald Meyers gate
# 2           Schous plass           nærmest rundkjøringen
# 3           Schous plass           nærmest rundkjøringen
# 4           Schous plass           nærmest rundkjøringen
# ...                  ...                             ...
# 57505      Bjølsen mølle  i Sandakerveien utenfor siloen
# 57506   Lodalen busstopp               langs Dyvekes vei
# 57507          Stensgata               ved trikkestoppet
# 57508   Vippetangen vest                nærmest Rådhuset
# 57509        Arkaden Sør            ved Dronningens gate
#
#        start_station_latitude  start_station_longitude  end_station_id  \
# 0                   59.920259                10.760629             381
# 1                   59.920259                10.760629             478
# 2                   59.920335                10.760804             422
# 3                   59.920335                10.760804             573
# 4                   59.920335                10.760804             396
# ...                       ...                      ...             ...
# 57505               59.939200                10.768774             567
# 57506               59.903453                10.777958            1101
# 57507               59.929634                10.732839            1101
# 57508               59.903989                10.740627             470
# 57509               59.911969                10.747858            1101
#
#                end_station_name                      end_station_description  \
# 0                Grønlands torg                              ved Tøyenbekken
# 1                Jernbanetorget                        på Europarådets plass
# 2                St. Hanshaugen                      i Waldemar Thranes gate
# 3            Tordenskiolds gate  Mellom Rådhusplassen og Otto Sverdrups gate
# 4                   Kirkeristen                                 ved Torggata
# ...                         ...                                          ...
# 57505           Forskningsveien                              ved Nordre Aker
# 57506         Stortingstunellen                               ved Rådhusgata
# 57507         Stortingstunellen                               ved Rådhusgata
# 57508  St. Hanshaugen park nord          krysset Colletts gt / Geitmyrsveien
# 57509         Stortingstunellen                               ved Rådhusgata
#
#        end_station_latitude  end_station_longitude  month combined     sum  \
# 0                 59.912520              10.762240      4   401381   32290
# 1                 59.911901              10.749929      4   401478   45174
# 2                 59.923703              10.740542      4   423422   26826
# 3                 59.911788              10.735165      4   423573   20496
# 4                 59.913032              10.746681      4   423396  142627
# ...                     ...                    ...    ...      ...     ...
# 57505             59.945478              10.713847     10   593567    1213
# 57506             59.910653              10.737365     10  7381101     752
# 57507             59.910653              10.737365     10  3821101     673
# 57508             59.929771              10.743524     10   452470    1157
# 57509             59.910653              10.737365     10  5451101     234
#
#       count
# 0      2633
# 1      2633
# 2      2633
# 3      2633
# 4      2633
# ...     ...
# 57505   272
# 57506   204
# 57507   597
# 57508  1092
# 57509   505
#
# [57510 rows x 18 columns]

# %%
result2['mul'] = result2['sum'].mul(result2['count'])

# %%
result_sort = result2.sort_values(['mul'], ascending=[False])
hh = result_sort[:10]

# %%
hh
# Out:
#        level_0                        started_at  \
# 4397      3987  2019-04-03 17:28:58.241000+00:00
# 4363        95  2019-04-03 04:54:01.563000+00:00
# 4440     12475  2019-04-04 19:31:03.056000+00:00
# 4475     25251  2019-04-06 15:58:50.512000+00:00
# 22231      544  2019-04-03 05:58:06.168000+00:00
# 4362        29  2019-04-03 04:24:57.231000+00:00
# 22695    24497  2019-04-06 14:52:29.173000+00:00
# 5219       595  2019-04-03 06:03:27.040000+00:00
# 5234      2457  2019-04-03 14:06:11.619000+00:00
# 4386      2415  2019-04-03 14:00:02.604000+00:00
#
#                                ended_at  duration  start_station_id  \
# 4397   2019-04-03 17:53:50.938000+00:00      1492               494
# 4363   2019-04-03 05:01:11.925000+00:00       430               494
# 4440   2019-04-04 19:43:06.259000+00:00       723               494
# 4475   2019-04-06 16:20:25.934000+00:00      1295               494
# 22231  2019-04-03 06:12:17.086000+00:00       850               479
# 4362   2019-04-03 04:34:14.505000+00:00       557               494
# 22695  2019-04-06 15:05:47.857000+00:00       798               478
# 5219   2019-04-03 06:22:26.086000+00:00      1139               398
# 5234   2019-04-03 14:12:48.151000+00:00       396               398
# 4386   2019-04-03 14:10:36.474000+00:00       633               494
#
#       start_station_name  start_station_description  start_station_latitude  \
# 4397      Rådhusbrygge 4            ved Nesoddbåten               59.910847
# 4363      Rådhusbrygge 4            ved Nesoddbåten               59.910847
# 4440      Rådhusbrygge 4            ved Nesoddbåten               59.910847
# 4475      Rådhusbrygge 4            ved Nesoddbåten               59.910847
# 22231         Tjuvholmen  nedenfor bussholdeplassen               59.909467
# 4362      Rådhusbrygge 4            ved Nesoddbåten               59.910847
# 22695     Jernbanetorget      på Europarådets plass               59.911901
# 5219        Ringnes Park             ved Sannergata               59.928520
# 5234        Ringnes Park             ved Sannergata               59.928520
# 4386      Rådhusbrygge 4            ved Nesoddbåten               59.910847
#
#        start_station_longitude  end_station_id       end_station_name  \
# 4397                 10.730377             494         Rådhusbrygge 4
# 4363                 10.730377             443           Sjøsiden øst
# 4440                 10.730377             392          Sjøsiden vest
# 4475                 10.730377             599              Paléhaven
# 22231                10.722509             479             Tjuvholmen
# 4362                 10.730377             464            Sukkerbiten
# 22695                10.749929             485        Sommerfrydhagen
# 5219                 10.760470             598  Sofienbergparken nord
# 5234                 10.760470             437          Sentrum Scene
# 4386                 10.730377             465               Bjørvika
#
#             end_station_description  end_station_latitude  \
# 4397                ved Nesoddbåten             59.910847
# 4363                nærmest trappen             59.910178
# 4440               nærmest fontenen             59.910178
# 4475               langs Strandgata             59.910331
# 22231     nedenfor bussholdeplassen             59.909467
# 4362      ved gangbroen til Sørenga             59.905037
# 22695           i Jens Bjelkes gate             59.911453
# 5219           langs Helgesens gate             59.923229
# 5234   ved Arbeidersamfunnets plass             59.915484
# 4386   ved broen under Nylandsveien             59.909006
#
#        end_station_longitude  month combined      sum count         mul
# 4397               10.730377      4   494494  1546825  6101  9437179325
# 4363               10.751824      4   494443   843761  6101  5147785861
# 4440               10.751224      4   494392   715447  6101  4364942147
# 4475               10.750110      4   494599   691644  6101  4219720044
# 22231              10.722509      4   479479  1208989  3301  3990872689
# 4362               10.753698      4   494464   647368  6101  3949592168
# 22695              10.776072      4   478485  1157967  3045  3526009515
# 5219               10.766171      4   398598  1082830  3039  3290720370
# 5234               10.751076      4   398437  1082021  3039  3288261819
# 4386               10.756180      4   494465   530546  6101  3236861146

# %%
print(out.shape)
print(result.shape)
print(df1.shape)
# Out:
# (1777, 3)
# (2060876, 17)
# (57544, 17)

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from folium) (1.19.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (2020.12.5)

# %%
import matplotlib.pyplot as plt

#installation
# Create a world map to show distributions of users 
import folium
from folium.plugins import MarkerCluster
#empty map
world_map= folium.Map(tiles="CartoDB dark_matter")
marker_cluster = MarkerCluster().add_to(world_map)
#for each coordinate, create circlemarker of user percent
for i in range(len(hh)):
        lat = hh.iloc[i]['start_station_latitude']
        long = hh.iloc[i]['start_station_longitude']
           
        
        radius=5
        popup_text = """Users : {}<br>"""
        popup_text = popup_text.format(hh.iloc[i]['start_station_name'])


        folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True).add_to(marker_cluster)

plt.savefig('x', dpi=300)
#show the map
world_map
#tiles="CartoDB dark_matter"
#cartodbpositron
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_93c49fc458dc4b4bbf26826be0a34cb7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_93c49fc458dc4b4bbf26826be0a34cb7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %%
import plotly.express as px

# %%
# select the first occurrence of each station id
locations = result2.groupby("start_station_id").first()
locations
# Out:
#                   level_0                        started_at  \
# start_station_id
# 377                   363  2019-04-03 05:40:31.213000+00:00
# 378                    59  2019-04-03 04:43:41.323000+00:00
# 380                   193  2019-04-03 05:17:22.981000+00:00
# 381                   546  2019-04-03 05:58:09.571000+00:00
# 382                  2117  2019-04-03 12:53:49.176000+00:00
# ...                   ...                               ...
# 787                  1152  2019-04-03 07:09:50.054000+00:00
# 970                764198  2019-06-20 14:58:03.525000+00:00
# 1009               983789  2019-07-10 19:12:50.147000+00:00
# 1023              1690222  2019-09-12 08:27:51.584000+00:00
# 1101                 7306  2019-10-01 15:23:49.250000+00:00
#
#                                           ended_at  duration  \
# start_station_id
# 377               2019-04-03 05:45:45.181000+00:00       313
# 378               2019-04-03 04:50:32.658000+00:00       411
# 380               2019-04-03 05:20:17.195000+00:00       174
# 381               2019-04-03 06:03:03.992000+00:00       294
# 382               2019-04-03 13:51:25.251000+00:00      3456
# ...                                            ...       ...
# 787               2019-04-03 07:16:39.616000+00:00       409
# 970               2019-06-20 15:02:22.574000+00:00       259
# 1009              2019-07-10 19:30:52.081000+00:00      1081
# 1023              2019-09-12 08:37:23.742000+00:00       572
# 1101              2019-10-01 15:32:20.902000+00:00       511
#
#                           start_station_name   start_station_description  \
# start_station_id
# 377                              Tøyenparken             ved Caltexløkka
# 378                           Colosseum Kino  langs Fridtjof Nansens vei
# 380                            Bentsebrugata        rett over busstoppet
# 381                           Grønlands torg             ved Tøyenbekken
# 382                                Stensgata           ved trikkestoppet
# ...                                      ...                         ...
# 787                             Kirkegata 15                Kirkegata 15
# 970                               Enerhaugen               ved Sørligata
# 1009                             Borgenveien             ved Holmenveien
# 1023              Professor Aschehougs plass       ved Kristian IVs gate
# 1101                       Stortingstunellen              ved Rådhusgata
#
#                   start_station_latitude  start_station_longitude  \
# start_station_id
# 377                            59.915667                10.777567
# 378                            59.929853                10.711515
# 380                            59.939230                10.759170
# 381                            59.912520                10.762240
# 382                            59.929634                10.732839
# ...                                  ...                      ...
# 787                            59.910156                10.743457
# 970                            59.913202                10.767579
# 1009                           59.942742                10.703833
# 1023                           59.914767                10.740971
# 1101                           59.910653                10.737365
#
#                   end_station_id           end_station_name  \
# start_station_id
# 377                          523                Tøyenbekken
# 378                          429                      Thune
# 380                          407      Sagene bussholdeplass
# 381                          465                   Bjørvika
# 382                          382                  Stensgata
# ...                          ...                        ...
# 787                          537             St. Olavs gate
# 970                          523                Tøyenbekken
# 1009                         421  Alexander Kiellands Plass
# 1023                         414              Kontraskjæret
# 1101                         568               Frognerveien
#
#                          end_station_description  end_station_latitude  \
# start_station_id
# 377                       Øst for Grønlands Torg             59.911594
# 378                                ved bomringen             59.922080
# 380                            ved Gråbeinsletta             59.937743
# 381                 ved broen under Nylandsveien             59.909006
# 382                            ved trikkestoppet             59.929634
# ...                                          ...                   ...
# 787                              ved Pilestredet             59.917986
# 970                       Øst for Grønlands Torg             59.911594
# 1009                           ved Maridalsveien             59.928058
# 1023              ved skråning ned mot Pipervika             59.910242
# 1101                            ved Vestheimgata             59.917085
#
#                   end_station_longitude  month combined     sum  count  \
# start_station_id
# 377                           10.761774      4   377523   45999    525
# 378                           10.685880      4   378429  126241    622
# 380                           10.751648      4   380407   47116    606
# 381                           10.756180      4   381465  119990   1857
# 382                           10.732839      4   382382  198538    669
# ...                                 ...    ...      ...     ...    ...
# 787                           10.738580      4   787537   20176    666
# 970                           10.761774      6   970523   25388    248
# 1009                          10.751397      7  1009421    7153     77
# 1023                          10.738570      9  1023414    1672    538
# 1101                          10.712880     10  1101568    1589    233
#
#                         mul
# start_station_id
# 377                24149475
# 378                78521902
# 380                28552296
# 381               222821430
# 382               132821922
# ...                     ...
# 787                13437216
# 970                 6296224
# 1009                 550781
# 1023                 899536
# 1101                 370237
#
# [253 rows x 18 columns]

# %%
# and select only the tree columns we are interested in
locations = locations.loc[:, ["start_station_latitude",
                              "start_station_longitude",
                              "start_station_name"]]

locations
# Out:
#                   start_station_latitude  start_station_longitude  \
# start_station_id
# 377                            59.915667                10.777567
# 378                            59.929853                10.711515
# 380                            59.939230                10.759170
# 381                            59.912520                10.762240
# 382                            59.929634                10.732839
# ...                                  ...                      ...
# 787                            59.910156                10.743457
# 970                            59.913202                10.767579
# 1009                           59.942742                10.703833
# 1023                           59.914767                10.740971
# 1101                           59.910653                10.737365
#
#                           start_station_name
# start_station_id
# 377                              Tøyenparken
# 378                           Colosseum Kino
# 380                            Bentsebrugata
# 381                           Grønlands torg
# 382                                Stensgata
# ...                                      ...
# 787                             Kirkegata 15
# 970                               Enerhaugen
# 1009                             Borgenveien
# 1023              Professor Aschehougs plass
# 1101                       Stortingstunellen
#
# [253 rows x 3 columns]

# %%
departure_counts =  result.groupby("start_station_id").count()
departure_counts
# select one column
departure_counts = departure_counts.iloc[:,[0]]
# and rename that column
departure_counts.columns= ["Departure Count"]
departure_counts
# Out:
#                   Departure Count
# start_station_id
# 377                          6536
# 378                          6019
# 380                          9130
# 381                         11319
# 382                          6689
# ...                           ...
# 787                          6046
# 970                          2585
# 1009                          864
# 1023                         1027
# 1101                           97
#
# [253 rows x 1 columns]

# %%
arrival_counts =  result.groupby("end_station_id").count()
arrival_counts
arrival_counts = arrival_counts.iloc[:,[0]]
arrival_counts.columns= ["arrival_counts"]
arrival_counts
# Out:
#                 arrival_counts
# end_station_id
# 377                       5392
# 378                       5908
# 380                       6094
# 381                      12004
# 382                       6490
# ...                        ...
# 787                       6147
# 970                       2500
# 1009                       541
# 1023                      1104
# 1101                       233
#
# [253 rows x 1 columns]

# %%
trip_counts = departure_counts.join(locations).join(arrival_counts)
trip_counts
# Out:
#                   Departure Count  start_station_latitude  \
# start_station_id
# 377                          6536               59.915667
# 378                          6019               59.929853
# 380                          9130               59.939230
# 381                         11319               59.912520
# 382                          6689               59.929634
# ...                           ...                     ...
# 787                          6046               59.910156
# 970                          2585               59.913202
# 1009                          864               59.942742
# 1023                         1027               59.914767
# 1101                           97               59.910653
#
#                   start_station_longitude          start_station_name  \
# start_station_id
# 377                             10.777567                 Tøyenparken
# 378                             10.711515              Colosseum Kino
# 380                             10.759170               Bentsebrugata
# 381                             10.762240              Grønlands torg
# 382                             10.732839                   Stensgata
# ...                                   ...                         ...
# 787                             10.743457                Kirkegata 15
# 970                             10.767579                  Enerhaugen
# 1009                            10.703833                 Borgenveien
# 1023                            10.740971  Professor Aschehougs plass
# 1101                            10.737365           Stortingstunellen
#
#                   arrival_counts
# start_station_id
# 377                         5392
# 378                         5908
# 380                         6094
# 381                        12004
# 382                         6490
# ...                          ...
# 787                         6147
# 970                         2500
# 1009                         541
# 1023                        1104
# 1101                         233
#
# [253 rows x 5 columns]

# %%
x= result['start_station_name'].unique().tolist()
y= result['end_station_name'].unique().tolist()
set(x) == set(y)  #arrival and departure stations are the same.
# Out:
# True

# %% [markdown]
# Now that our data is ready, let’s add it to the map. We’ll iterate over all the rows in the DataFrame we just created and add a marker for each row. We assign a different color depending on the sign of the net departures. If there are more departures than arrivals, we draw a tangerine circle, other wise we use teal.

# %%
import folium
from folium.plugins import MarkerCluster
#empty map
folium_map= folium.Map(tiles="CartoDB dark_matter")
marker_cluster = MarkerCluster().add_to(world_map)

for index, row in trip_counts.iterrows():
    net_departures = (row["Departure Count"]-row["arrival_counts"])
    radius = net_departures/800
    if net_departures>0:
        color="#E37222" # tangerine
    else:
        color="#0A8A9F" # teal
    #popup_text = """Users : {}<br>"""
    #popup_text = popup_text.format(hh.iloc[i]['start_station_name'])
    
    popup_text = """{}<br>
                total departures: {}<br> 
                total arrivals: {}<br>
                net departures: {}"""
    popup_text = popup_text.format(row["start_station_name"],
                               row["arrival_counts"],
                               row["Departure Count"],
                               net_departures)
    folium.CircleMarker(location=(row["start_station_latitude"],
                                  row["start_station_longitude"]),
                        radius=radius,
                        color=color,
                        fill=True,popup= popup_text).add_to(folium_map)
   




    
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1c24d4bd8521491599589f33bd9d015a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1c24d4bd8521491599589f33bd9d015a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1c24d4bd8521491599589f33bd9d015a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1c24d4bd8521491599589f33bd9d015a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# customize the effect of overlapping paths to show traffic density, and
# we will add a glow effect to draw attention to high density areas.

# %% [markdown]
# Creating the intensity map
# Adding lines: We will start by creating a gray scale image where intensity in each pixel is proportional to the number of trips passing through that pixel. We’ll use a numpy array to store the pixel values.

# %%
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
import folium
import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.colors import LinearSegmentedColormap, rgb_to_hsv, hsv_to_rgb
import scipy.ndimage.filters

# %%
def add_lines(image_array, xys, width=1, weights=None):
    """
    Add a set of lines (xys) to an existing image_array
    width: width of lines
    weights: [], optional list of multipliers for lines. 
    """
    
    for i, xy in enumerate(xys):  # loop over lines
        # create a new gray scale image
        image = Image.new("L",(image_array.shape[1], image_array.shape[0]))
        
        # draw the line
        ImageDraw.Draw(image).line(xy, 200, width=width)
        
        #convert to array
        new_image_array = np.asarray(image, dtype=np.uint8).astype(float)
        
        # apply weights if provided
        if weights is not None:
            new_image_array *= weights[i]
            
        # add to existing array
        image_array += new_image_array

    # convolve image
    new_image_array = scipy.ndimage.filters.convolve(image_array, get_kernel(width*4)) 
    return new_image_array

# %%
def get_kernel(kernel_size, blur=1/20, halo=.001):
    """
    Create an (n*2+1)x(n*2+1) numpy array.
    Output can be used as the kernel for convolution.
    """
    
    # generate x and y grids
    x, y = np.mgrid[0:kernel_size*2+1, 0:kernel_size*2+1]
    
    center = kernel_size + 1  # center pixel
    r = np.sqrt((x - center)**2 + (y - center)**2)  # distance from center
    
    # now compute the kernel. This function is a bit arbitrary. 
    # adjust this to get the effect you want.
    kernel = np.exp(-r/kernel_size/blur) + (1 - r/r[center,0]).clip(0)*halo
    return kernel

# %%
def to_image(array, hue=.62):
    """converts an array of floats to an array of RGB values using a colormap"""
    
    # apply saturation function
    image_data = np.log(array + 1)
    
    # create colormap, change these values to adjust to look of your plot
    saturation_values = [[0, 0], [1, .68], [.78, .87], [0, 1]]
    colors = [hsv_to_rgb([hue, x, y]) for x, y in saturation_values]
    cmap = LinearSegmentedColormap.from_list("my_colormap", colors)
    
    # apply colormap
    out = cmap(image_data/image_data.max())
    
    # convert to 8-bit unsigned integer
    out = (out*255).astype(np.uint8)
    return out

# %% [markdown]
# Convert Latitude and Longitude to Pixel Coordinates: Since folium (and leaflet.js) uses Mercator projection we can convert easily from latitude/longitude coordinates to pixel coordinates using a multiplier (i.e., y_pixel = A*latitude, x_pixel= B* longitude). We will choose A and B so that all our paths fit in the image and have the right aspect ratio.

# %%
min_lat = result["start_station_latitude"].min()
max_lat = result["start_station_latitude"].max()
max_lon = result["start_station_longitude"].max()
min_lon = result["start_station_longitude"].min()

def latlon_to_pixel(lat, lon, image_shape):
    # longitude to pixel conversion (fit data to image)
    delta_x = image_shape[1]/(max_lon-min_lon)
    
    # latitude to pixel conversion (maintain aspect ratio)
    delta_y = delta_x/np.cos(lat/360*np.pi*2)
    pixel_y = (max_lat-lat)*delta_y
    pixel_x = (lon-min_lon)*delta_x
    return (pixel_y,pixel_x)

# %% [markdown]
# and we’ll create a quick convenience function that applies this conversion to rows in our dataframe:

# %%
def row_to_pixel(row,image_shape):
    """
    convert a row (1 trip) to pixel coordinates
    of start and end point
    """
    start_y, start_x = latlon_to_pixel(row["start_station_latitude"], 
                                       row["start_station_longitude"], image_shape)
    end_y, end_x = latlon_to_pixel(row["end_station_latitude"], 
                                   row["end_station_longitude"], image_shape)
    xy = (start_x, start_y, end_x, end_y)
    return xy

# %%
#test
''''paths = result
paths = paths.iloc[:3000,:]
# generate empty pixel array, choose your resolution
image_data = np.zeros((900,400))
# generate pixel coordinates of starting points and end points
xys = [row_to_pixel(row, image_data.shape) for i, row in paths.iterrows()]
# draw the lines
image_data = add_lines(image_data, xys, weights=None, width = 1)
Image.fromarray(to_image(image_data*10)[:,:,:3],mode="RGB")'''
# Out:
# <PIL.Image.Image image mode=RGB size=400x900 at 0x7F8BCF63A8D0>

# %%
def add_alpha(image_data):
    """
    Uses the Value in HSV as an alpha channel. 
    This creates an image that blends nicely with a black background.
    """
    
    # get hsv image
    hsv = rgb_to_hsv(image_data[:,:,:3].astype(float)/255)
    
    # create new image and set alpha channel
    new_image_data = np.zeros(image_data.shape)
    new_image_data[:,:,3] = hsv[:,:,2]
    
    # set value of hsv image to either 0 or 1.
    hsv[:,:,2] = np.where(hsv[:,:,2]>0, 1, 0)
    
    # combine alpha and new rgb
    new_image_data[:,:,:3] = hsv_to_rgb(hsv)
    return new_image_data

# %%
# create the map
import folium
from folium.plugins import MarkerCluster
# create the map
folium_map = folium.Map(location=[59.9139, 10.7522],
                        zoom_start=13,
                        tiles="CartoDB dark_matter",
                        width='50%')

# create the overlay
map_overlay = add_alpha(to_image(image_data*10))

# compute extent of image in lat/lon
aspect_ratio = map_overlay.shape[1]/map_overlay.shape[0]
delta_lat = (max_lon-min_lon)/aspect_ratio*np.cos(min_lat/360*2*np.pi)

# add the image to the map
img = folium.raster_layers.ImageOverlay(map_overlay,
                           bounds = [(max_lat-delta_lat,min_lon),(max_lat,max_lon)],
                           opacity = 1,
                           name = "Paths")

img.add_to(folium_map)
folium.LayerControl().add_to(folium_map)

# show the map
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_49359df4f0a54b61b08d2a4568720e07%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2050.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.leaflet-image-layer%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20/%2A%20old%20android/safari%2A/%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20-webkit-optimize-contrast%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20crisp-edges%3B%20/%2A%20safari%20%2A/%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20pixelated%3B%20/%2A%20chrome%20%2A/%0A%20%20%20%20%20%20%20%20 ...
